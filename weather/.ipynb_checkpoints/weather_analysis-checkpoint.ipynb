# %%
import pandas as pd
import numpy as np
import requests
import json
from scipy.stats import linregress
from citipy import citipy
import random
from config import api_key
import time
import matplotlib.pyplot as plt

# %%
# exploring citypy
#https://github.com/wingchen/citipy#looking-up-with-coordinates
city = citipy.nearest_city(41.8, -87.6)

# %%
city.city_name
# Out:
# 'chicago'

# %%
city.country_code
# Out:
# 'us'

# %%
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
lat_lngs = []
cities = []

# %%
lats = np.random.uniform(-90, 90, size = 1500)
longs = np.random.uniform(-180, 180, size = 1500)

# %%
lat_longs=pd.DataFrame({"latitude":lats,
                       "longitude":longs})
# putting these intermediate variables in dataframes instead of lists 
# to prevent weirdness with blank values

# %%
lat_longs
# Out:
#        latitude   longitude
# 0    -80.184261 -136.762062
# 1      1.012677  -32.503254
# 2     47.466412  151.248134
# 3     23.379857    4.114560
# 4    -57.649519 -131.628807
# ...         ...         ...
# 1495 -11.048267  166.377770
# 1496  71.478361  175.818792
# 1497  13.056244  159.721780
# 1498 -28.924678 -112.860003
# 1499 -16.243002   89.792044
#
# [1500 rows x 2 columns]

# %%
cities = []

for index, row in lat_longs.iterrows():
    city = citipy.nearest_city(row["latitude"], row["longitude"]).city_name
    
    if city not in cities:
        cities.append(city)

# %%
len(cities)
# Out:
# 619

# %%
weather=pd.DataFrame({"city":cities,
                    "latitude":"",
                      "longitude":"",
                      "temperature":"",
                      "humidity":"",
                      "cloudiness":"",
                      "wind":"",
                      "datetime":"",
                      "country":""})

weather.head()
# Out:
#        city latitude longitude temperature humidity cloudiness wind datetime  \
# 0   rikitea
# 1    touros
# 2    vostok
# 3  tessalit
# 4  flinders
#
#   country
# 0
# 1
# 2
# 3
# 4

# %%
# open weather api:
# https://openweathermap.org/current
# https://api.openweathermap.org/data/2.5/weather?q={city name}&appid={API key}

# %%
# running an api call on open weather with one test city

# %%
test = "husavik"

# %%
response = requests.get(f"http://api.openweathermap.org/data/2.5/weather?q={test}&appid={api_key}&units=imperial").json()

# %%
print(json.dumps(response, indent=4, sort_keys=True))
# Out:
# {
#     "base": "stations",
#     "clouds": {
#         "all": 20
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 66.0449,
#         "lon": -17.3389
#     },
#     "dt": 1620145198,
#     "id": 2629833,
#     "main": {
#         "feels_like": 34.23,
#         "humidity": 41,
#         "pressure": 1025,
#         "temp": 39.2,
#         "temp_max": 39.2,
#         "temp_min": 39.2
#     },
#     "name": "Husavik",
#     "sys": {
#         "country": "IS",
#         "id": 83,
#         "sunrise": 1620101602,
#         "sunset": 1620165526,
#         "type": 1
#     },
#     "timezone": 0,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "few clouds",
#             "icon": "02d",
#             "id": 801,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 180,
#         "speed": 6.91
#     }
# }

# %%
#locating info in the open weather json

#latitude
response["coord"]["lat"]
# Out:
# 66.0449

# %%
#longitude
response["coord"]["lon"]
# Out:
# -17.3389

# %%
#temp
response["main"]["temp"]
# Out:
# 39.2

# %%
#humidity
response["main"]["humidity"]
# Out:
# 41

# %%
#cloudiness
response["clouds"]["all"]
# Out:
# 20

# %%
#wind
response["wind"]["speed"]
# Out:
# 6.91

# %%
#datetime
response["dt"]
# Out:
# 1620145198

# %%
#country
response["sys"]["country"]
# Out:
# 'IS'

# %%
for index, row in weather.iterrows():
    city = row["city"]
    
    not_json_yet = requests.get(f"http://api.openweathermap.org/data/2.5/weather?q={city}&appid={api_key}&units=imperial")
    
    if not_json_yet.status_code == 200:
        
        response = not_json_yet.json()
    
        weather.loc[index, "latitude"] = response["coord"]["lat"]
        weather.loc[index, "longitude"] = response["coord"]["lon"]
        weather.loc[index, "temperature"] = response["main"]["temp"]
        weather.loc[index, "humidity"] = response["main"]["humidity"]
        weather.loc[index, "cloudiness"] = response["clouds"]["all"]
        weather.loc[index, "wind"] = response["wind"]["speed"]
        weather.loc[index, "datetime"] = response["dt"]
        weather.loc[index, "country"] = response["sys"]["country"]
    
        print(f"Pulling weather for city #{index}, {city}")
    
        time.sleep(1)
        #to prevent maxing out the api call, thanks to Shaun in the class slack for the syntax!
    
    else: 
        print(f"no data for city #{index}, {city}")
# Out:
# Pulling weather for city #0, rikitea
# Pulling weather for city #1, touros
# Pulling weather for city #2, vostok
# Pulling weather for city #3, tessalit
# Pulling weather for city #4, flinders
# no data for city #5, yomitan
# Pulling weather for city #6, nanortalik
# no data for city #7, belushya guba
# Pulling weather for city #8, cape town
# Pulling weather for city #9, santa rosa
# Pulling weather for city #10, bengkulu
# Pulling weather for city #11, faanui
# Pulling weather for city #12, lebu
# Pulling weather for city #13, kapaa
# Pulling weather for city #14, inhambane
# Pulling weather for city #15, krasnogorskoye
# Pulling weather for city #16, lagoa
# no data for city #17, barentsburg
# Pulling weather for city #18, ystad
# Pulling weather for city #19, saint george
# Pulling weather for city #20, ushuaia
# Pulling weather for city #21, pampas
# Pulling weather for city #22, butaritari
# Pulling weather for city #23, albany
# Pulling weather for city #24, fort nelson
# Pulling weather for city #25, rio gallegos
# Pulling weather for city #26, winneba
# Pulling weather for city #27, nishihara
# Pulling weather for city #28, busselton
# Pulling weather for city #29, sobolevo
# Pulling weather for city #30, punta arenas
# Pulling weather for city #31, puerto boyaca
# Pulling weather for city #32, vilhena
# Pulling weather for city #33, kodiak
# Pulling weather for city #34, bluff
# Pulling weather for city #35, saint-philippe
# Pulling weather for city #36, castro
# Pulling weather for city #37, vaini
# Pulling weather for city #38, georgetown
# Pulling weather for city #39, torbay
# no data for city #40, palabuhanratu
# Pulling weather for city #41, ponta do sol
# Pulling weather for city #42, mataura
# no data for city #43, umzimvubu
# no data for city #44, tarudant
# Pulling weather for city #45, tuatapere
# Pulling weather for city #46, yellowknife
# Pulling weather for city #47, cayenne
# Pulling weather for city #48, chokurdakh
# no data for city #49, illoqqortoormiut
# Pulling weather for city #50, ternate
# Pulling weather for city #51, mamallapuram
# Pulling weather for city #52, puerto ayora
# Pulling weather for city #53, abong mbang
# Pulling weather for city #54, hasaki
# Pulling weather for city #55, san juan
# Pulling weather for city #56, tura
# Pulling weather for city #57, lompoc
# Pulling weather for city #58, jimenez
# Pulling weather for city #59, fukue
# Pulling weather for city #60, fort-shevchenko
# Pulling weather for city #61, antofagasta
# no data for city #62, ozgon
# Pulling weather for city #63, asau
# Pulling weather for city #64, hilo
# Pulling weather for city #65, praia da vitoria
# Pulling weather for city #66, osa
# Pulling weather for city #67, doctor phillips
# Pulling weather for city #68, eruwa
# Pulling weather for city #69, hobyo
# Pulling weather for city #70, hermanus
# no data for city #71, taolanaro
# Pulling weather for city #72, chuy
# Pulling weather for city #73, okhotsk
# Pulling weather for city #74, saskylakh
# Pulling weather for city #75, woodstock
# Pulling weather for city #451, yellandu
# Pulling weather for city #452, chengzihe
# Pulling weather for city #453, carutapera
# Pulling weather for city #454, petropavlovsk-kamchatskiy
# Pulling weather for city #455, tsumeb
# Pulling weather for city #456, wewak
# Pulling weather for city #457, agustin codazzi
# Pulling weather for city #458, amapa
# Pulling weather for city #459, fujin
# Pulling weather for city #460, vorukh
# Pulling weather for city #461, talaja
# Pulling weather for city #462, shimoda
# Pulling weather for city #463, geraldton
# no data for city #464, warqla
# Pulling weather for city #465, dukat
# Pulling weather for city #466, pithapuram
# Pulling weather for city #467, straza
# Pulling weather for city #468, zhezkazgan
# Pulling weather for city #469, ust-nera
# Pulling weather for city #470, diffa
# Pulling weather for city #471, basco
# Pulling weather for city #472, dalbandin
# Pulling weather for city #473, manama
# Pulling weather for city #474, kudat
# Pulling weather for city #475, baykit
# Pulling weather for city #476, cairns
# Pulling weather for city #477, umm lajj
# Pulling weather for city #478, labuan
# Pulling weather for city #479, aklavik
# Pulling weather for city #480, san angelo
# Pulling weather for city #481, lardos
# no data for city #482, bobonong
# Pulling weather for city #483, palembang
# Pulling weather for city #484, abbeville
# Pulling weather for city #485, neiafu
# Pulling weather for city #486, whyalla
# Pulling weather for city #487, turtas
# Pulling weather for city #488, aviemore
# Pulling weather for city #489, sorland
# Pulling weather for city #490, onega
# Pulling weather for city #491, muravlenko
# Pulling weather for city #492, shelburne
# Pulling weather for city #493, cockburn town
# Pulling weather for city #494, katangli
# Pulling weather for city #495, burton
# Pulling weather for city #496, payakumbuh
# Pulling weather for city #497, kabanjahe
# Pulling weather for city #498, chebarkul
# Pulling weather for city #499, itupiranga
# Pulling weather for city #500, meadow lake
# Pulling weather for city #501, luganville
# Pulling weather for city #502, dodge city
# Pulling weather for city #503, mogadishu
# Pulling weather for city #504, mitsamiouli
# Pulling weather for city #505, sioux lookout
# Pulling weather for city #506, polican
# no data for city #507, formoso do araguaia
# Pulling weather for city #508, port macquarie
# Pulling weather for city #509, sumenep
# Pulling weather for city #510, fangshan
# Pulling weather for city #511, hervey bay
# Pulling weather for city #512, coolum beach
# Pulling weather for city #513, christchurch
# Pulling weather for city #514, hargeysa
# Pulling weather for city #515, adoni
# Pulling weather for city #516, jalu
# Pulling weather for city #517, durango
# Pulling weather for city #518, bontang
# Pulling weather for city #519, krasnyy yar
# Pulling weather for city #520, sistranda
# Pulling weather for city #521, sao joao da barra
# Pulling weather for city #522, hamilton
# Pulling weather for city #523, nizwa
# Pulling weather for city #524, salalah
# Pulling weather for city #525, mount gambier
# Pulling weather for city #526, altagracia de orituco
# Pulling weather for city #527, san martin
# Pulling weather for city #528, lahij
# Pulling weather for city #529, qarqin
# Pulling weather for city #530, belchatow
# Pulling weather for city #531, druzhba
# no data for city #532, saleaula
# Pulling weather for city #533, stolin
# no data for city #534, kamenskoye
# Pulling weather for city #535, kupang
# Pulling weather for city #536, panaba
# Pulling weather for city #537, dasoguz
# Pulling weather for city #538, lamu
# Pulling weather for city #539, wadi musa
# Pulling weather for city #540, korla
# Pulling weather for city #541, sadiqabad
# Pulling weather for city #542, gat
# Pulling weather for city #543, ribe
# Pulling weather for city #544, los alamos
# Pulling weather for city #545, morro bay
# Pulling weather for city #546, teya
# Pulling weather for city #547, harper
# Pulling weather for city #548, chamonix-mont-blanc
# Pulling weather for city #549, oskarshamn
# Pulling weather for city #550, omboue
# Pulling weather for city #551, santa maria da vitoria
# Pulling weather for city #552, morros
# Pulling weather for city #553, lorengau
# Pulling weather for city #554, bonavista
# Pulling weather for city #555, hannibal
# no data for city #556, bargal
# Pulling weather for city #557, pochutla
# Pulling weather for city #558, abu dhabi
# Pulling weather for city #559, filadelfia
# Pulling weather for city #560, ulladulla
# Pulling weather for city #561, ntcheu
# no data for city #562, halalo
# Pulling weather for city #563, corni
# Pulling weather for city #564, orlik
# Pulling weather for city #565, ancud
# Pulling weather for city #566, niamey
# Pulling weather for city #567, barsovo
# no data for city #568, satitoa
# Pulling weather for city #569, boyolangu
# Pulling weather for city #570, tarkwa
# Pulling weather for city #571, coquimbo
# Pulling weather for city #572, finschhafen
# Pulling weather for city #573, tabou
# Pulling weather for city #574, zhanaozen
# Pulling weather for city #575, san jeronimo
# Pulling weather for city #576, klyuchi
# Pulling weather for city #577, ulcinj
# Pulling weather for city #578, naranjal
# Pulling weather for city #579, bonga
# Pulling weather for city #580, pizarro
# Pulling weather for city #581, saint-georges
# Pulling weather for city #582, turukhansk
# Pulling weather for city #583, byron bay
# Pulling weather for city #584, likasi
# Pulling weather for city #585, kashi
# Pulling weather for city #586, baherden
# Pulling weather for city #587, south lake tahoe
# Pulling weather for city #588, gazli
# Pulling weather for city #589, shingu
# Pulling weather for city #590, chapleau
# Pulling weather for city #591, nakamura
# Pulling weather for city #592, san cristobal
# Pulling weather for city #593, bambanglipuro
# Pulling weather for city #594, alice springs
# Pulling weather for city #595, udachnyy
# Pulling weather for city #596, aksarka
# Pulling weather for city #597, saquarema
# Pulling weather for city #598, elizabeth city
# Pulling weather for city #599, urumqi
# Pulling weather for city #600, ondjiva
# Pulling weather for city #601, rajshahi
# Pulling weather for city #602, nurota
# Pulling weather for city #603, galeana
# Pulling weather for city #604, havre-saint-pierre
# Pulling weather for city #605, christiansburg
# Pulling weather for city #606, toamasina
# Pulling weather for city #607, barcelos
# Pulling weather for city #608, ortakoy
# Pulling weather for city #609, palasa
# Pulling weather for city #610, valleyview
# Pulling weather for city #611, pandharpur
# Pulling weather for city #612, river falls
# Pulling weather for city #613, manto
# Pulling weather for city #614, acapulco
# Pulling weather for city #615, kavieng
# Pulling weather for city #616, agbor
# no data for city #617, gilgil
# Pulling weather for city #618, freeport

# %%
weather
# Out:
#          city latitude longitude temperature humidity cloudiness   wind  \
# 0     rikitea -23.1203  -134.969       78.64       80         10  12.24
# 1      touros  -5.1989  -35.4608        82.4       74         75   11.5
# 2      vostok  46.4856   135.883       38.79       92        100   5.93
# 3    tessalit  20.1986    1.0114      106.77        2          0   6.64
# 4    flinders -34.5833   150.855       58.57       94        100   1.01
# ..        ...      ...       ...         ...      ...        ...    ...
# 614  acapulco  16.8634  -99.8901        84.2       51          1   8.05
# 615   kavieng  -2.5744   150.797        82.2       75         30   0.98
# 616     agbor   6.2518    6.1934       81.46       71        100   5.53
# 617    gilgil
# 618  freeport  40.6576  -73.5832       62.33       77         75   3.44
#
#        datetime country
# 0    1620145198      PF
# 1    1620145199      BR
# 2    1620145201      RU
# 3    1620145202      ML
# 4    1620145203      AU
# ..          ...     ...
# 614  1620145686      MX
# 615  1620145961      PG
# 616  1620145962      NG
# 617
# 618  1620145922      US
#
# [619 rows x 9 columns]

# %%
# dropping the rows that didn't get any info returned in the api call
weather.drop(weather.loc[weather["latitude"] == "",:].index, inplace=True)
# borrowed from https://stackoverflow.com/questions/13851535/how-to-delete-rows-from-a-pandas-dataframe-based-on-a-conditional-expression

# %%
weather
# Out:
#          city latitude longitude temperature humidity cloudiness   wind  \
# 0     rikitea -23.1203  -134.969       78.64       80         10  12.24
# 1      touros  -5.1989  -35.4608        82.4       74         75   11.5
# 2      vostok  46.4856   135.883       38.79       92        100   5.93
# 3    tessalit  20.1986    1.0114      106.77        2          0   6.64
# 4    flinders -34.5833   150.855       58.57       94        100   1.01
# ..        ...      ...       ...         ...      ...        ...    ...
# 613     manto  14.9167  -86.3833        84.2       61         75    6.6
# 614  acapulco  16.8634  -99.8901        84.2       51          1   8.05
# 615   kavieng  -2.5744   150.797        82.2       75         30   0.98
# 616     agbor   6.2518    6.1934       81.46       71        100   5.53
# 618  freeport  40.6576  -73.5832       62.33       77         75   3.44
#
#        datetime country
# 0    1620145198      PF
# 1    1620145199      BR
# 2    1620145201      RU
# 3    1620145202      ML
# 4    1620145203      AU
# ..          ...     ...
# 613  1620145959      HN
# 614  1620145686      MX
# 615  1620145961      PG
# 616  1620145962      NG
# 618  1620145922      US
#
# [573 rows x 9 columns]

# %%
#printing to csv
weather.to_csv("results/weather_data.csv", index=False)

# %%
# scatter plots

# data note: my cities list doesn't have any latitudes below -60, but it's not a sampling
# problem. There just aren't any cities below that latitude!

# %%
plt.scatter(weather["latitude"], weather["temperature"])
plt.title("Latitude vs. Temperature")
plt.ylabel("Temperature (F)")
plt.xlabel("Latitude")
plt.savefig("results/temperature.png")

# %%
# Each dot in this scatterplot represents one city. Its position on the x axis shows 
# how farth north or south it is on earth, with 0 as the equator. Its position on the 
# y axis shows how hot it was there at the time the data was pulled.

# %%
plt.scatter(weather["latitude"], weather["humidity"])
plt.title("Latitude vs. Humidity")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.savefig("results/humidity.png")

# %%
# Each dot in this scatterplot represents one city. Its position on the x axis shows 
# how farth north or south it is on earth, with 0 as the equator. Its position on the 
# y axis shows how humid it was there at the time the data was pulled.

# %%
plt.scatter(weather["latitude"], weather["cloudiness"])
plt.title("Latitude vs. Cloudiness")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.savefig("results/clouds.png")

# %%
# Each dot in this scatterplot represents one city. Its position on the x axis shows how 
# farth north or south it is on earth, with 0 as the equator. Its position on the y axis 
# shows how cloudy it was there at the time the data was pulled. The horizontal bands 
# probably mean that the data isn't precise down to 1% - many data points are 
# probably estimates of 0%, 20%, 40% etc. cloud cover.

# %%
plt.scatter(weather["latitude"], weather["wind"])
plt.title("Latitude vs. Wind Speed")
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.savefig("results/wind.png")

# %%
# Each dot in this scatterplot represents one city. Its position on the x axis shows how 
# farth north or south it is on earth, with 0 as the equator. Its position on the y axis 
# shows the wind speed at the time the data was pulled.

# %%
# regressions!

# %%
north = weather.loc[weather["latitude"]>0,:]
south = weather.loc[weather["latitude"]<=0,:]

# %%
fig, (south_sub, north_sub) = plt.subplots(nrows=1, ncols=2, sharey=True, figsize=(12, 6))
fig.suptitle("Latitude vs. Temperature")
south_sub.set_ylabel("Temperature (F)")
south_sub.set_xlabel("Latitude")

south_sub.scatter(south["latitude"],south["temperature"])
south_sub.set_title("Southern Hemisphere")

(south_slope, south_intercept, south_rvalue, south_pvalue, south_stderr) = linregress(south["latitude"].astype(float),south["temperature"].astype(float))
south_regress = south["latitude"] * south_slope + south_intercept
south_line = "y = " + str(round(south_slope,2)) + "x + " + str(round(south_intercept,2))

south_sub.plot(south["latitude"],south_regress,"r-")
south_sub.annotate(south_line,(-40,25),fontsize=15,color="red")


north_sub.scatter(north["latitude"],north["temperature"])
north_sub.set_title("Northern Hemisphere")
north_sub.set_xlabel("Latitude")

(north_slope, north_intercept, north_rvalue, north_pvalue, north_stderr) = linregress(north["latitude"].astype(float),north["temperature"].astype(float))
north_regress = north["latitude"] * north_slope + north_intercept
north_line = "y = " + str(round(north_slope,2)) + "x + " + str(round(north_intercept,2))

north_sub.plot(north["latitude"],north_regress,"r-")
north_sub.annotate(north_line,(5,25),fontsize=15,color="red")

plt.savefig("results/N&S temperature with regressions.png")

# cast df columns as floats based on this thread: https://stackoverflow.com/questions/53200129/attributeerror-float-object-has-no-attribute-shape-when-using-linregress
# after getting an error in the linear regression

# %%
north_line
# Out:
# 'y = 0.01x + 8.44'

# %%
# The linear regression shows how much temperature varies with latitude in each hemisphere 
# at the time the data was pulled. In each case, temperature decreases with latitudes farther 
# away from the equator. At the moment it varies much more with latitude in the northern 
# hemisphere, most likely because it is winter here, so temperatures are able to get lower.
# But, I expect that if we re ran this in July, we would still not see as strong a correlation 
# in southern hemisphere as we do now for the northern hemisphere, because the cities in 
# the southern hemisphere are much more clustered in the tropical & subtropical regions (about
# <35 degrees latitude) where temperatures vary less with the seasons.

# %%
fig, (south_sub, north_sub) = plt.subplots(nrows=1, ncols=2, sharey=True, figsize=(12, 6))
fig.suptitle("Latitude vs. Humidity")
south_sub.set_ylabel("Humidity (%)")

south_sub.scatter(south["latitude"],south["humidity"])
south_sub.set_title("Southern Hemisphere")
south_sub.set_xlabel("Latitude")

(south_slope, south_intercept, south_rvalue, south_pvalue, south_stderr) = linregress(south["latitude"].astype(float),south["humidity"].astype(float))
south_regress = south["latitude"] * south_slope + south_intercept
south_line = "y = " + str(round(south_slope,2)) + "x + " + str(round(south_intercept,2))

south_sub.plot(south["latitude"],south_regress,"r-")
south_sub.annotate(south_line,(-40,10),fontsize=15,color="red")


north_sub.scatter(north["latitude"],north["humidity"])
north_sub.set_title("Northern Hemisphere")
north_sub.set_xlabel("Latitude")

(north_slope, north_intercept, north_rvalue, north_pvalue, north_stderr) = linregress(north["latitude"].astype(float),north["humidity"].astype(float))
north_regress = north["latitude"] * north_slope + north_intercept
north_line = "y = " + str(round(north_slope,2)) + "x + " + str(round(north_intercept,2))

north_sub.plot(north["latitude"],north_regress,"r-")
north_sub.annotate(north_line,(40,20),fontsize=15,color="red")

plt.savefig("results/N&S humidity with regressions.png")

# %%
# The linear regression shows how much humidity varies with latitude in each hemisphere at 
# the time the data was pulled. In the southern hemisphere, humidity increases as latitudes 
# approach the equator, but in the northern hemisphere, they decrease. The Northern
# hemisphere's results are strongly affected by the sahara desert (lat 10-30 ish and of course, 
# very dry).

# %%
fig, (south_sub, north_sub) = plt.subplots(nrows=1, ncols=2, sharey=True, figsize=(12, 6))
fig.suptitle("Latitude vs. Cloudiness")
south_sub.set_ylabel("Cloud Cover (%)")
south_sub.set_xlabel("Latitude")

south_sub.scatter(south["latitude"],south["cloudiness"])
south_sub.set_title("Southern Hemisphere")

(south_slope, south_intercept, south_rvalue, south_pvalue, south_stderr) = linregress(south["latitude"].astype(float),south["cloudiness"].astype(float))
south_regress = south["latitude"] * south_slope + south_intercept
south_line = "y = " + str(round(south_slope,2)) + "x + " + str(round(south_intercept,2))

south_sub.plot(south["latitude"],south_regress,"r-")
south_sub.annotate(south_line,(-50,60),fontsize=15,color="red")

north_sub.scatter(north["latitude"],north["cloudiness"])
north_sub.set_title("Northern Hemisphere")
north_sub.set_xlabel("Latitude")

(north_slope, north_intercept, north_rvalue, north_pvalue, north_stderr) = linregress(north["latitude"].astype(float),north["cloudiness"].astype(float))
north_regress = north["latitude"] * north_slope + north_intercept
north_line = "y = " + str(round(north_slope,2)) + "x + " + str(round(north_intercept,2))

north_sub.plot(north["latitude"],north_regress,"r-")
north_sub.annotate(north_line,(40,45),fontsize=15,color="red")

plt.savefig("results/N&S cloud cover with regressions.png")

# %%
# The linear regression shows how much humidity varies with latitude in each hemisphere 
# at the time the data was pulled. In the southern hemisphere, cloud cover increases as 
# latitudes approach the equator, but in the northern hemisphere, it decreases. This is 
# most likely an effect of humidity.

# %%
fig, (south_sub, north_sub) = plt.subplots(nrows=1, ncols=2, sharey=True, figsize=(12, 6))
fig.suptitle("Latitude vs. Wind Speed")
south_sub.set_ylabel("Wind Speed (mph)")

south_sub.scatter(south["latitude"],south["wind"])
south_sub.set_title("Southern Hemisphere")
south_sub.set_xlabel("Latitude")

(south_slope, south_intercept, south_rvalue, south_pvalue, south_stderr) = linregress(south["latitude"].astype(float),south["wind"].astype(float))
south_regress = south["latitude"] * south_slope + south_intercept
south_line = "y = " + str(round(south_slope,2)) + "x + " + str(round(south_intercept,2))

south_sub.plot(south["latitude"],south_regress,"r-")
south_sub.annotate(south_line,(-40,30),fontsize=15,color="red")

north_sub.scatter(north["latitude"],north["wind"])
north_sub.set_title("Northern Hemisphere")
north_sub.set_xlabel("Latitude")

(north_slope, north_intercept, north_rvalue, north_pvalue, north_stderr) = linregress(north["latitude"].astype(float),north["wind"].astype(float))
north_regress = north["latitude"] * north_slope + north_intercept
north_line = "y = " + str(round(north_slope,2)) + "x + " + str(round(north_intercept,2))

north_sub.plot(north["latitude"],north_regress,"r-")
north_sub.annotate(north_line,(0,30),fontsize=15,color="red")

plt.savefig("results/N&S wind speed with regressions.png")

# %%
# The linear regression shows how much wind speed varies with latitude in each hemisphere 
# at the time the data was pulled. In both hemispheres there is no strong correlation between
# wind speed and latitude. But every time I've run this you can spot Tierra Del Fuego 
# (latitude <-50 and always really stormy) in the top left corner of the southern hemisphere 
# plot.

# %%
#Tierra Del Fuego!

weather.loc[weather["latitude"]<-50,:]
# Out:
#             city latitude longitude temperature humidity cloudiness   wind  \
# 20       ushuaia    -54.8     -68.3        46.4       66         75  25.32
# 25  rio gallegos -51.6226  -69.2181        44.6       57          0  23.02
# 30  punta arenas   -53.15  -70.9167        46.2       71         75  25.32
#
#       datetime country
# 20  1620145066      AR
# 25  1620145227      AR
# 30  1620145234      CL
