# %%
import pandas as pd
import requests
import json
from config import gkey
import gmaps

# %%
gmaps.configure(api_key=gkey)

# %%
# pulling in the data from weatherpy
weather_url = "../weatherpy/results/weather_data.csv"

# %%
weather = pd.read_csv(weather_url)

# %%
weather.head()
# Out:
#             city  latitude  longitude  temperature  humidity  cloudiness  \
# 0   punta arenas  -53.1500   -70.9167        48.09        66          75
# 1      kirovskiy   45.0917   133.5136       -23.69        86           4
# 2  san cristobal    7.7669   -72.2250        84.20        58          40
# 3     maningrida  -12.0667   134.2667        76.30        91          81
# 4       necochea  -38.5473   -58.7368        78.01        42          35
#
#     wind    datetime country
# 0  25.32  1611948215      CL
# 1   2.57  1611948216      RU
# 2  13.80  1611947928      VE
# 3   6.11  1611948218      AU
# 4   6.80  1611948219      AR

# %%
weather.dtypes
# Out:
# city            object
# latitude       float64
# longitude      float64
# temperature    float64
# humidity         int64
# cloudiness       int64
# wind           float64
# datetime         int64
# country         object
# dtype: object

# %%
#data for heatmap

locations = weather[["latitude", "longitude"]]
humidity = weather["humidity"].astype(float)

# %%
#heatmap

fig = gmaps.figure()

heat_layer = gmaps.heatmap_layer(locations, weights=humidity, 
                                 dissipating=False, max_intensity=100,
                                 point_radius = 2)

fig.add_layer(heat_layer)

fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
#choosing vacation spots

vacation_spots = weather.loc[(weather["temperature"]>77)&
            (weather["temperature"]<83)&
            (weather["cloudiness"]<20)&
            (weather["wind"]<10)&
            (weather["humidity"]>40)&
            (weather["humidity"]<80),:]

vacation_spots["hotel"]=""

vacation_spots
# Out:
# <ipython-input-91-90dfc5f80fd2>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vacation_spots["hotel"]=""
#              city  latitude  longitude  temperature  humidity  cloudiness  \
# 271      freetown    8.4840   -13.2299        79.56        74           0
# 304     kavaratti   10.5669    72.6420        80.51        73           1
# 421     caravelas  -17.7125   -39.2481        81.30        68           0
# 466      karratha  -20.7377   116.8463        81.52        76          12
# 554   grand gaube  -20.0064    57.6608        81.00        77           7
# 565  saint-joseph  -21.3667    55.6167        77.88        69           0
#
#      wind    datetime country hotel
# 271  8.39  1611948436      SL
# 304  9.42  1611948567      IN
# 421  9.31  1611948706      BR
# 466  4.07  1611948762      AU
# 554  5.99  1611948876      MU
# 565  4.61  1611948890      RE

# %%
#test api call with one city to decipher the json

url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

location = "66.045,-17.338"

params = {
    "location": location,
    "radius": "10000",
    "keyword": "hotel",
    "key": gkey,
}

response = requests.get(url, params=params).json()

# %%
print(json.dumps(response, indent=4, sort_keys=True))
# Out:
# {
#     "html_attributions": [],
#     "results": [
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 66.0460305,
#                     "lng": -17.3397434
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 66.04740452989273,
#                         "lng": -17.33827452010728
#                     },
#                     "southwest": {
#                         "lat": 66.04470487010728,
#                         "lng": -17.34097417989272
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Fosshotel H\u00fasav\u00edk",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 427,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/110948050126192662565\">Fosshotel H\u00fasav\u00edk</a>"
#                     ],
#                     "photo_reference": "ATtYBwI-L9JrYAP4bHg8zSgKecQiAB79JC_g_NRj6TlI6Rhbn-_uAi7LW_nW0cbgINjdcf5soLYXorZubYzjrLDi4ICyk_uYu4xCJCLvJLRLFC8E1EW8SB3ihXp2xf7Rr9QjVZdxKmBxPOllwVDDO2gcfac6zIbXn2mHrtmU0pAhUzDiCt48",
#                     "width": 640
#                 }
#             ],
#             "place_id": "ChIJJ8mMCTxCzUgRs3NObzGnrDk",
#             "plus_code": {
#                 "compound_code": "2MW6+C4 H\u00fasav\u00edk, Iceland",
#                 "global_code": "9CR42MW6+C4"
#             },
#             "rating": 4.4,
#             "reference": "ChIJJ8mMCTxCzUgRs3NObzGnrDk",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "restaurant",
#                 "food",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 366,
#             "vicinity": "Ketilsbraut 22, H\u00fasav\u00edk"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 65.9717508,
#                     "lng": -17.3868405
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 65.97311717989271,
#                         "lng": -17.38536822010728
#                     },
#                     "southwest": {
#                         "lat": 65.97041752010726,
#                         "lng": -17.38806787989272
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Laxh\u00fas",
#             "photos": [
#                 {
#                     "height": 2322,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/101107903534655299181\">MARC RAES</a>"
#                     ],
#                     "photo_reference": "ATtYBwK9jOQR9SGFAbhEA5CuUDagRGrzgsqt8H1VYDXiAbE181f90uE4RlnGqPwWpQfgr-k_8SNRCnrfc9DUXU6yR5SbJPh-M9S0EWCeNNAkb4ul8wJD2WeH3i199Js-Reasnrh8W0X2UGq85ng9-l6aEuC2kFP2c723tIG80N5r9KTO4gJ2",
#                     "width": 4128
#                 }
#             ],
#             "place_id": "ChIJi43Cv19ozUgRu6E81bcXvOw",
#             "plus_code": {
#                 "compound_code": "XJC7+P7 Laxam\u00fdri, Iceland",
#                 "global_code": "9CQ4XJC7+P7"
#             },
#             "rating": 4.5,
#             "reference": "ChIJi43Cv19ozUgRu6E81bcXvOw",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 24,
#             "vicinity": "Nor\u00f0austurvegur Laxam\u00fdri, Laxamyri"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 66.0463707,
#                     "lng": -17.336129
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 66.04796927989271,
#                         "lng": -17.33498097010728
#                     },
#                     "southwest": {
#                         "lat": 66.04526962010728,
#                         "lng": -17.33768062989272
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Gamli Sk\u00f3linn H\u00fasav\u00edk",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 2160,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/108220706702457593673\">Tanel Laansalu</a>"
#                     ],
#                     "photo_reference": "ATtYBwL6yyMWrybSAFU3M6eNC8cBgXnE6g0LBLv-4BsEs_B1ToHIgQl-USefK5bA4M6zfHSPCGS3m2yfCE1_GgrkIWmcCn9ig9YW00GlubwoYNeQAfmgYrM177QrYg4ZbMI7yIJ6ZKqsiJPBiPtSrEqXKsvqPN8zj89zJE2gJ3L-kJP86bO6",
#                     "width": 3840
#                 }
#             ],
#             "place_id": "ChIJkwn2gRZCzUgRRPDmZsiGEA0",
#             "plus_code": {
#                 "compound_code": "2MW7+GG Nor\u00f0ur\u00feing, Iceland",
#                 "global_code": "9CR42MW7+GG"
#             },
#             "rating": 4.7,
#             "reference": "ChIJkwn2gRZCzUgRRPDmZsiGEA0",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 21,
#             "vicinity": "St\u00f3rigar\u00f0ur 6, Nor\u00f0ur\u00feing"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 65.99903,
#                     "lng": -17.3630891
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 66.00043072989271,
#                         "lng": -17.36166307010728
#                     },
#                     "southwest": {
#                         "lat": 65.99773107010728,
#                         "lng": -17.36436272989272
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Saltv\u00edk Farm Guesthouse",
#             "place_id": "ChIJZx36RzVozUgRy4bJ4Kd-xmU",
#             "plus_code": {
#                 "compound_code": "XJXP+JQ H\u00fasav\u00edk, Iceland",
#                 "global_code": "9CQ4XJXP+JQ"
#             },
#             "rating": 5,
#             "reference": "ChIJZx36RzVozUgRy4bJ4Kd-xmU",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 2,
#             "vicinity": "Saltv\u00edk, H\u00fasav\u00edk"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 66.0451932,
#                     "lng": -17.3412852
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 66.04652692989272,
#                         "lng": -17.33996767010728
#                     },
#                     "southwest": {
#                         "lat": 66.04382727010727,
#                         "lng": -17.34266732989272
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Hofdi Apartment",
#             "photos": [
#                 {
#                     "height": 4032,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/118398632005876288761\">Iza \u0141.</a>"
#                     ],
#                     "photo_reference": "ATtYBwKdMLUb7lq2uQLLrh5Qo0fe7NypebNtcETReX1qzwAB-JOHOYDBLurL-Di-vr-iXGX_4j9cj31Zoe39GJS1W7qE3dhH__f3ietPpnaB7Ns4RHXslppDfY8e-fcA7Y6ML_pLzA-SEkyLPQTNU0SmawI8uxOkkkN6DDutzxBF1uEIonOt",
#                     "width": 3024
#                 }
#             ],
#             "place_id": "ChIJ7TUGWRRCzUgRcO9cmV47RYw",
#             "plus_code": {
#                 "compound_code": "2MW5+3F H\u00fasav\u00edk, Iceland",
#                 "global_code": "9CR42MW5+3F"
#             },
#             "rating": 4.5,
#             "reference": "ChIJ7TUGWRRCzUgRcO9cmV47RYw",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 8,
#             "vicinity": "Gar\u00f0arsbraut, H\u00fasav\u00edk"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 66.02414,
#                     "lng": -17.3608439
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 66.02499402989272,
#                         "lng": -17.3521157
#                     },
#                     "southwest": {
#                         "lat": 66.02229437010729,
#                         "lng": -17.3637533
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Guesthouses cottages.is",
#             "photos": [
#                 {
#                     "height": 3024,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/100843604907752541322\">Diana Masselle</a>"
#                     ],
#                     "photo_reference": "ATtYBwL3KdbG1Hi787bcq8WYOuVo1FJzgRAMC2G27HzwRBm-rmT85KNcsjmjhlS73Vjb0h4hJwncgyCl3XoyW5ocKgUChKM0BayFq9zojKEuhiidKI2SGl0Y4hM3ULg9ywXUZXh6PyS3jojPrqZRZhorO7-n5rT6wkouGd_ZVHWOVeHe4XnA",
#                     "width": 4032
#                 }
#             ],
#             "place_id": "ChIJ173Y735CzUgR5WnfMaKmIP8",
#             "plus_code": {
#                 "compound_code": "2JFQ+MM H\u00fasav\u00edk, Iceland",
#                 "global_code": "9CR42JFQ+MM"
#             },
#             "rating": 4.7,
#             "reference": "ChIJ173Y735CzUgR5WnfMaKmIP8",
#             "scope": "GOOGLE",
#             "types": [
#                 "real_estate_agency",
#                 "travel_agency",
#                 "lodging",
#                 "park",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 6,
#             "vicinity": "Nor\u00f0austurvegur, H\u00fasav\u00edk"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 66.048585,
#                     "lng": -17.3541709
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 66.04992882989272,
#                         "lng": -17.35284197010728
#                     },
#                     "southwest": {
#                         "lat": 66.04722917010729,
#                         "lng": -17.35554162989272
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "H\u00fasav\u00edk Cape Hotel",
#             "photos": [
#                 {
#                     "height": 3024,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/100734523441198702897\">Aaron Archambault</a>"
#                     ],
#                     "photo_reference": "ATtYBwLY_ow0GqNDwtUEs8eT_yJWRGsYUXaFXMo6hk1SZKXl1ksZK18vojdcT559mPuNC9HZehy3v_-J9V4CISsK-A5dN4T-qEHlC4hQI7RttJ54emapZthNvFZXb7D2KdHpUNXBKR0wkhrLHFMHwkn0uNJ-XTMAheE5Nm_lEDkyIySwU_iu",
#                     "width": 4032
#                 }
#             ],
#             "place_id": "ChIJJ8mMCTxCzUgRNyIpY27sn2c",
#             "plus_code": {
#                 "compound_code": "2JXW+C8 H\u00fasav\u00edk, Iceland",
#                 "global_code": "9CR42JXW+C8"
#             },
#             "rating": 4.2,
#             "reference": "ChIJJ8mMCTxCzUgRNyIpY27sn2c",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 91,
#             "vicinity": "H\u00f6f\u00f0i, H\u00fasav\u00edk"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 66.0423368,
#                     "lng": -17.3394999
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 66.04368032989271,
#                         "lng": -17.33807402010728
#                     },
#                     "southwest": {
#                         "lat": 66.04098067010727,
#                         "lng": -17.34077367989272
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Hofdi Apartments Gardarsbraut 15",
#             "photos": [
#                 {
#                     "height": 2160,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/108220706702457593673\">Tanel Laansalu</a>"
#                     ],
#                     "photo_reference": "ATtYBwJVwCs52JSJKgDqyN4yk1McDxMIJxIPIzzqSgi_xRRBXBRrLgEXlXCMJxNTUhAaFaPoJiaxEOwO9eAtEzfacCVfLfnDDCVdcwJpnLEOehEJkYI0eWMYbfz4IG1_j6d7Vom-1pOVf8BD9ltH40L26NoEoXLfYR9hJs9p-q42IZCCFVCM",
#                     "width": 3840
#                 }
#             ],
#             "place_id": "ChIJadEydhNCzUgRGUYp4_RCQh4",
#             "plus_code": {
#                 "compound_code": "2MR6+W6 H\u00fasav\u00edk, Iceland",
#                 "global_code": "9CR42MR6+W6"
#             },
#             "rating": 3.7,
#             "reference": "ChIJadEydhNCzUgRGUYp4_RCQh4",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 11,
#             "vicinity": "Gar\u00f0arsbraut 15, H\u00fasav\u00edk"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 66.0010755,
#                     "lng": -17.3649429
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 66.00245302989272,
#                         "lng": -17.36355422010728
#                     },
#                     "southwest": {
#                         "lat": 65.99975337010727,
#                         "lng": -17.36625387989272
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Saltv\u00edk Guesthouse",
#             "photos": [
#                 {
#                     "height": 3265,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/100710693362812767125\">Ferran d&#39; Armengol</a>"
#                     ],
#                     "photo_reference": "ATtYBwIDgp7k6njDyBOliT1TQSOFPW_nIfZZcABOIlMMsCTxFuVlDD4a2BNJG8Z6tfP4zZ2Kv-iKeVhh9Y8zej5C5iDHso-KGcMrg93wIafaMsuZJe39s19DNn3idGLdyR5dN2hK3UcKspbuPufQ8PV8JjW_yM14Ap2M5imYFgq-pKh9c9Q",
#                     "width": 4898
#                 }
#             ],
#             "place_id": "ChIJYyjH2jRozUgRQl2O_uwN8us",
#             "plus_code": {
#                 "compound_code": "2J2P+C2 H\u00fasav\u00edk, Iceland",
#                 "global_code": "9CR42J2P+C2"
#             },
#             "rating": 4.6,
#             "reference": "ChIJYyjH2jRozUgRQl2O_uwN8us",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 41,
#             "vicinity": "Saltv\u00edk, Nor\u00f0austurvegur"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 66.045473,
#                     "lng": -17.3422229
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 66.04681297989272,
#                         "lng": -17.34094682010728
#                     },
#                     "southwest": {
#                         "lat": 66.04411332010727,
#                         "lng": -17.34364647989272
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Askja Apartment",
#             "place_id": "ChIJpdBf-BRCzUgRjkn9xXh8QiM",
#             "plus_code": {
#                 "compound_code": "2MW5+54 H\u00fasav\u00edk, Iceland",
#                 "global_code": "9CR42MW5+54"
#             },
#             "rating": 5,
#             "reference": "ChIJpdBf-BRCzUgRjkn9xXh8QiM",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 2,
#             "vicinity": "Gar\u00f0arsbraut 18, H\u00fasav\u00edk"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 66.0448239,
#                     "lng": -17.3392405
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 66.04606107989272,
#                         "lng": -17.33811687010728
#                     },
#                     "southwest": {
#                         "lat": 66.04336142010727,
#                         "lng": -17.34081652989272
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Post-Plaza Guesthouse",
#             "photos": [
#                 {
#                     "height": 2160,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/108220706702457593673\">Tanel Laansalu</a>"
#                     ],
#                     "photo_reference": "ATtYBwJAcYfZPUQ9sgxtECOVlA8JKdBPVBp5F9np6pgouNQ63swxIU8zGCEe4lLm7DbsMOy-g6CMv-cMpYW6bT-IgBraP1OehaBLGX053ovmp19qPzCEmNtpgoQW8oTj-4ho3vio6NK4w0rfJmTXMOyVNf_o0j23VYbBvMR_IuSpd_Ie_bnm",
#                     "width": 3840
#                 }
#             ],
#             "place_id": "ChIJH6YHhTtDzUgRcc-8gNlN_V8",
#             "plus_code": {
#                 "compound_code": "2MV6+W8 H\u00fasav\u00edk, Iceland",
#                 "global_code": "9CR42MV6+W8"
#             },
#             "rating": 4.3,
#             "reference": "ChIJH6YHhTtDzUgRcc-8gNlN_V8",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 21,
#             "vicinity": "Gar\u00f0arsbraut 21, H\u00fasav\u00edk"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 66.0467227,
#                     "lng": -17.3389335
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 66.04798992989272,
#                         "lng": -17.33751842010728
#                     },
#                     "southwest": {
#                         "lat": 66.04529027010727,
#                         "lng": -17.34021807989272
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Skj\u00e1lfandi Apartments",
#             "photos": [
#                 {
#                     "height": 2160,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/108220706702457593673\">Tanel Laansalu</a>"
#                     ],
#                     "photo_reference": "ATtYBwJV6CvlypH7eCgLKiugFYyOKxttiNC_gS7718we1gOrxMh_VYFahVg8RuNo3c3yACL5kzhrDjJfdO7dW2J4dw1eI4Ov75g1a14MsMGbT9wJ3qIZJOCNheZQc86h_P5Gv9lL-qaKYHTZZH4ld6Ev9ZYk2IL_86QQGOqWPdsmOOyWIyta",
#                     "width": 3840
#                 }
#             ],
#             "place_id": "ChIJvTI9tRVCzUgRrpu6AQMRsIk",
#             "plus_code": {
#                 "compound_code": "2MW6+MC H\u00fasav\u00edk, Iceland",
#                 "global_code": "9CR42MW6+MC"
#             },
#             "rating": 4.6,
#             "reference": "ChIJvTI9tRVCzUgRrpu6AQMRsIk",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 16,
#             "vicinity": "St\u00f3rigar\u00f0ur 13, H\u00fasav\u00edk"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 65.96388700000001,
#                     "lng": -17.351188
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 65.96461850000001,
#                         "lng": -17.35045110000001
#                     },
#                     "southwest": {
#                         "lat": 65.9616925,
#                         "lng": -17.3533987
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png",
#             "name": "M\u00fdvatn Road Guesthouse",
#             "photos": [
#                 {
#                     "height": 1152,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/101276128782263183180\">Marco Mannucci</a>"
#                     ],
#                     "photo_reference": "ATtYBwJVsgDhzKYZ1eXLjq6tFjVnpCfFDhWIv3l2GbqZQ-08uPqbvmTj2iuISNxjfKfrEwfH6DvB7FDkrVzOPNo5QzjpLwG443BxpgNco_kGpXGL5vu6gXUnIHgdBeCDOWrW94ifmgAuICNb0S_8URqajd58W53bdJbPiYwyRhAUjwELVQM1",
#                     "width": 2048
#                 }
#             ],
#             "place_id": "ChIJkWsFHvtozUgR2nYWvvKP5Gw",
#             "plus_code": {
#                 "compound_code": "XJ7X+HG H\u00fasav\u00edk, Iceland",
#                 "global_code": "9CQ4XJ7X+HG"
#             },
#             "rating": 5,
#             "reference": "ChIJkWsFHvtozUgR2nYWvvKP5Gw",
#             "scope": "GOOGLE",
#             "types": [
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 1,
#             "vicinity": "Hr\u00edsateigur 2, North Iceland, H\u00fasav\u00edk"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 66.0426083,
#                     "lng": -17.3403112
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 66.04397372989271,
#                         "lng": -17.33918387010728
#                     },
#                     "southwest": {
#                         "lat": 66.04127407010728,
#                         "lng": -17.34188352989272
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Guesthouse Sigt\u00fan",
#             "photos": [
#                 {
#                     "height": 3024,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/112338515486566720062\">sbernauer.dv09</a>"
#                     ],
#                     "photo_reference": "ATtYBwLZ5Z160ijQqnubdwi2fgZjeLBbGNBcqvAPG8pSaQvGeEBCpxHkpxWKqffWeaIKSjOfDMMv4UDW2t33hkak_Owq_Mj6kAZp3BoBU9V6HI0UdnpTh-EvNr0SuD2SmHtY6ZVaI7jCuO58HumbwbhYzmydKLm8VcsKIzmAkLKH8WCkf9VD",
#                     "width": 4032
#                 }
#             ],
#             "place_id": "ChIJ1VEvZBNCzUgR5lfovDGnMVM",
#             "plus_code": {
#                 "compound_code": "2MV5+2V H\u00fasav\u00edk, Iceland",
#                 "global_code": "9CR42MV5+2V"
#             },
#             "rating": 4.3,
#             "reference": "ChIJ1VEvZBNCzUgR5lfovDGnMVM",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 34,
#             "vicinity": "T\u00fangata 13, H\u00fasav\u00edk"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 66.0475926,
#                     "lng": -17.3408997
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 66.04887077989272,
#                         "lng": -17.33948527010728
#                     },
#                     "southwest": {
#                         "lat": 66.04617112010727,
#                         "lng": -17.34218492989272
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "H\u00fasav\u00edk Green Hostel",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 937,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/115728781658595250033\">Husavik Hostel</a>"
#                     ],
#                     "photo_reference": "ATtYBwIzrT0Tqjb0yiGyrpnz-YuBwnjXsW6XNgSlVzf62dMZPzpPZZuyI9ysyv_A48K2YtZtakhf1RSO5wOmYp7Exqz78F24LKMhdkL2HhO3ZEG1oScaqi0h77vQVwazIBOcech91aIrY1jRjzkzw--U-vS7TewkwTBHa9D3W8lQLGbkPomj",
#                     "width": 1300
#                 }
#             ],
#             "place_id": "ChIJmV730xJCzUgRz6QXl7Eo6Rc",
#             "plus_code": {
#                 "compound_code": "2MX5+2J H\u00fasav\u00edk, Iceland",
#                 "global_code": "9CR42MX5+2J"
#             },
#             "rating": 4.2,
#             "reference": "ChIJmV730xJCzUgRz6QXl7Eo6Rc",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 40,
#             "vicinity": "Vallholtsvegur, H\u00fasav\u00edk"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 66.0453055,
#                     "lng": -17.3421374
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 66.04665287989272,
#                         "lng": -17.34080307010727
#                     },
#                     "southwest": {
#                         "lat": 66.04395322010728,
#                         "lng": -17.34350272989272
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Port Guesthouse",
#             "photos": [
#                 {
#                     "height": 2268,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/109116768220708086967\">Roberto Erisi</a>"
#                     ],
#                     "photo_reference": "ATtYBwLB_dNFTdQMz-cYgzu9g5bNda4kKvylz3XYSPbppIX7QXpIhLx_Ro9QD7HIjMgT92Tt-y4WyKrJGhGcNIcfT6aAPOorPwFuvNNbyAkdQr1_vNI7xQTccaTS0Kb4nzPWwD7Byx9LSsmugj6V4qWtZIMC5eDCwYEYL-LY-wCXfAd3Kj8E",
#                     "width": 4032
#                 }
#             ],
#             "place_id": "ChIJbUcn-BRCzUgRR0EBjgqReI0",
#             "plus_code": {
#                 "compound_code": "2MW5+44 H\u00fasav\u00edk, Iceland",
#                 "global_code": "9CR42MW5+44"
#             },
#             "rating": 4.5,
#             "reference": "ChIJbUcn-BRCzUgRR0EBjgqReI0",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 27,
#             "vicinity": "Mararbraut, H\u00fasav\u00edk"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 65.95566389999999,
#                     "lng": -17.5458664
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 65.95697767989272,
#                         "lng": -17.54462207010727
#                     },
#                     "southwest": {
#                         "lat": 65.95427802010728,
#                         "lng": -17.54732172989272
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Berg HI Hostel",
#             "photos": [
#                 {
#                     "height": 1667,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/105650255706497682681\">Berg</a>"
#                     ],
#                     "photo_reference": "ATtYBwJrdrEPJpAnI0x3fmQ6Ey943G0Y-JWngzUXj8p4B5AlufRA6FYuX7dE9s_VnM-kLn-fIriYofWZ3w8LfFM_NrL2mSM1_tK0H1X6Y8l3hy3xXQLnbB0YlPM7lBK8eF4vXBL1BLO8krF1BiXk_P6CmBYpxF11Lnm9lp_yCuL5X1pBW4Vk",
#                     "width": 2500
#                 }
#             ],
#             "place_id": "ChIJU7nV2ANnzUgRu_dXm-tMjdk",
#             "plus_code": {
#                 "compound_code": "XF43+7M H\u00fasav\u00edk, Iceland",
#                 "global_code": "9CQ4XF43+7M"
#             },
#             "rating": 4.1,
#             "reference": "ChIJU7nV2ANnzUgRu_dXm-tMjdk",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 30,
#             "vicinity": "Berg 641, H\u00fasav\u00edk"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 66.048464,
#                     "lng": -17.345931
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 66.04990067989272,
#                         "lng": -17.34398512010728
#                     },
#                     "southwest": {
#                         "lat": 66.04720102010728,
#                         "lng": -17.34668477989272
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "H\u00f6f\u00f0i guesthouse",
#             "photos": [
#                 {
#                     "height": 3024,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/108788113109458497077\">kh allen</a>"
#                     ],
#                     "photo_reference": "ATtYBwLqaIW9LNJVWk7TdO5NpvaeRTIiBw65JlKYenIUcE2CLcuErgYVcLZs3fkubVFEwQQePlYPfsqttiHyfS1WpGiMJSfqQrOTKMmXn_KnGVlTSBZ3eJfiKIh3buLZDmLnzFBPZAn3s08PeeRsmBVkhnhiqAOlVHVoxOXfZ9KdCwdLDWs6",
#                     "width": 4032
#                 }
#             ],
#             "place_id": "ChIJkUswfRVCzUgRwUTh89rSpis",
#             "plus_code": {
#                 "compound_code": "2MX3+9J H\u00fasav\u00edk, Iceland",
#                 "global_code": "9CR42MX3+9J"
#             },
#             "rating": 4.4,
#             "reference": "ChIJkUswfRVCzUgRwUTh89rSpis",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 41,
#             "vicinity": "H\u00e9\u00f0insbraut, H\u00fasav\u00edk"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 66.0440929,
#                     "lng": -17.3381994
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 66.0455039298927,
#                         "lng": -17.33679587010728
#                     },
#                     "southwest": {
#                         "lat": 66.04280427010727,
#                         "lng": -17.33949552989272
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Arbol",
#             "photos": [
#                 {
#                     "height": 1728,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/106889869776847980008\">Laxic Hsiao</a>"
#                     ],
#                     "photo_reference": "ATtYBwJoCMIhjd3KnSar7T1R5x6BYaGipLwi4PfAi5bFsHSHpZmhgli5TVt3Yi3srI2a5c_l65FMlq8i_s0J3x17DEWNh9__r7j0tmjJfucnPOYsWQevr4zW21x20lk-y2N6R_cyHEdNUAgg38mQRu_tvZQbbEzdM7szXZT1OYhxmhW4aIcg",
#                     "width": 2592
#                 }
#             ],
#             "place_id": "ChIJacL_bxRCzUgR7m3J1T1h8DA",
#             "plus_code": {
#                 "compound_code": "2MV6+JP H\u00fasav\u00edk, Iceland",
#                 "global_code": "9CR42MV6+JP"
#             },
#             "rating": 4.5,
#             "reference": "ChIJacL_bxRCzUgR7m3J1T1h8DA",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 81,
#             "vicinity": "\u00c1sgar\u00f0svegur, H\u00fasav\u00edk"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 66.04641889999999,
#                     "lng": -17.3398669
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 66.04779867989272,
#                         "lng": -17.33854102010728
#                     },
#                     "southwest": {
#                         "lat": 66.04509902010727,
#                         "lng": -17.34124067989272
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png",
#             "name": "H\u00fasav\u00edk apartments",
#             "place_id": "ChIJkwn2gRZCzUgRD5APNe97EQ4",
#             "rating": 0,
#             "reference": "ChIJkwn2gRZCzUgRD5APNe97EQ4",
#             "scope": "GOOGLE",
#             "types": [
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 0,
#             "vicinity": "St\u00f3rigar\u00f0ur, H\u00fasav\u00edk"
#         }
#     ],
#     "status": "OK"
# }

# %%
#hotel name
response["results"][0]["name"]
# Out:
# 'Fosshotel Húsavík'

# %%
#running the real api call for my vacation spots

url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

for index, row in vacation_spots.iterrows():
    
    location = f"{row['latitude']}, {row['longitude']}"
    
    params = {
    "location": location,
    "radius": "10000",
    "keyword": "hotel",
    "key": gkey}
    
    response = requests.get(url, params=params).json()
    
    vacation_spots.loc[index, "hotel name"] = response["results"][0]["name"]
# Out:
# /Users/leah/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:1596: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = _infer_fill_value(value)
# /Users/leah/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:1765: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value)

# %%
vacation_spots
# Out:
#              city  latitude  longitude  temperature  humidity  cloudiness  \
# 271      freetown    8.4840   -13.2299        79.56        74           0
# 304     kavaratti   10.5669    72.6420        80.51        73           1
# 421     caravelas  -17.7125   -39.2481        81.30        68           0
# 466      karratha  -20.7377   116.8463        81.52        76          12
# 554   grand gaube  -20.0064    57.6608        81.00        77           7
# 565  saint-joseph  -21.3667    55.6167        77.88        69           0
#
#      wind    datetime country hotel                               hotel name
# 271  8.39  1611948436      SL        Radisson Blu Mammy Yoko Hotel, Freetown
# 304  9.42  1611948567      IN                    Bismillah Hotel And Lodging
# 421  9.31  1611948706      BR                              Abrolhos Dive Inn
# 466  4.07  1611948762      AU                           ibis Styles Karratha
# 554  5.99  1611948876      MU                 Sea Resorts Hotels Head Office
# 565  4.61  1611948890      RE                               Palm Hotel & Spa

# %%
# adding hotels to heatmap
# setting marker locations
marker_locations = vacation_spots[['latitude', 'longitude']]

marker_locations
# Out:
#      latitude  longitude
# 271    8.4840   -13.2299
# 304   10.5669    72.6420
# 421  -17.7125   -39.2481
# 466  -20.7377   116.8463
# 554  -20.0064    57.6608
# 565  -21.3667    55.6167

# %%
#setting up info box content in a list

marker_box_list = []

for index, row in vacation_spots.iterrows():
    marker_box = {"Hotel":row["hotel name"], "City":row["city"], "Country":row["country"]}
    marker_box_list.append(marker_box)

# %%
marker_box_list
# Out:
# [{'Hotel': 'Radisson Blu Mammy Yoko Hotel, Freetown',
#   'City': 'freetown',
#   'Country': 'SL'},
#  {'Hotel': 'Bismillah Hotel And Lodging',
#   'City': 'kavaratti',
#   'Country': 'IN'},
#  {'Hotel': 'Abrolhos Dive Inn', 'City': 'caravelas', 'Country': 'BR'},
#  {'Hotel': 'ibis Styles Karratha', 'City': 'karratha', 'Country': 'AU'},
#  {'Hotel': 'Sea Resorts Hotels Head Office',
#   'City': 'grand gaube',
#   'Country': 'MU'},
#  {'Hotel': 'Palm Hotel & Spa', 'City': 'saint-joseph', 'Country': 'RE'}]

# %%
# Found this template that made it look way better at https://jupyter-gmaps.readthedocs.io/en/latest/tutorial.html
# otherwise it was just a string

info_box_template = """
<dl>
<dt>Hotel</dt><dd>{Hotel}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
</dl>
"""

hotel_info = [info_box_template.format(**hotel) for hotel in marker_box_list]

# %%
markers = gmaps.marker_layer(marker_locations, info_box_content=hotel_info)
                             
fig.add_layer(markers)
                             
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
