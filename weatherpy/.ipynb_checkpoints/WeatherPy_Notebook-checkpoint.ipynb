# %%
import pandas as pd
import numpy as np
import requests
import json
from scipy.stats import linregress
from citipy import citipy
import random
from config import api_key
import time
import matplotlib.pyplot as plt

# %%
# exploring citypy
#https://github.com/wingchen/citipy#looking-up-with-coordinates
city = citipy.nearest_city(41.8, -87.6)

# %%
city.city_name
# Out:
# 'chicago'

# %%
city.country_code
# Out:
# 'us'

# %%
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
lat_lngs = []
cities = []

# %%
lats = np.random.uniform(-90, 90, size = 1500)
longs = np.random.uniform(-180, 180, size = 1500)

# %%
lat_longs=pd.DataFrame({"latitude":lats,
                       "longitude":longs})
# putting these intermediate variables in dataframes instead of lists 
# to prevent weirdness with blank values

# %%
lat_longs
# Out:
#        latitude   longitude
# 0    -85.604032 -111.656194
# 1     45.086606   78.199850
# 2     -8.365982  -89.880216
# 3     -9.670463  134.204299
# 4    -41.351828  -57.536471
# ...         ...         ...
# 1495 -83.531168   76.699912
# 1496 -79.306922  -75.096675
# 1497  24.771900  171.280538
# 1498 -52.021185   73.955616
# 1499  36.729806    6.131073
#
# [1500 rows x 2 columns]

# %%
cities = []

for index, row in lat_longs.iterrows():
    city = citipy.nearest_city(row["latitude"], row["longitude"]).city_name
    
    if city not in cities:
        cities.append(city)

# %%
len(cities)
# Out:
# 631

# %%
weather=pd.DataFrame({"city":cities,
                    "latitude":"",
                      "longitude":"",
                      "temperature":"",
                      "humidity":"",
                      "cloudiness":"",
                      "wind":"",
                      "datetime":"",
                      "country":""})

weather.head()
# Out:
#             city latitude longitude temperature humidity cloudiness wind  \
# 0   punta arenas
# 1      kirovskiy
# 2  san cristobal
# 3     maningrida
# 4       necochea
#
#   datetime country
# 0
# 1
# 2
# 3
# 4

# %%
# open weather api:
# https://openweathermap.org/current
# https://api.openweathermap.org/data/2.5/weather?q={city name}&appid={API key}

# %%
# running an api call on open weather with one test city

# %%
test = "husavik"

# %%
response = requests.get(f"http://api.openweathermap.org/data/2.5/weather?q={test}&appid={api_key}&units=imperial").json()

# %%
print(json.dumps(response, indent=4, sort_keys=True))
# Out:
# {
#     "base": "stations",
#     "clouds": {
#         "all": 75
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 66.0449,
#         "lon": -17.3389
#     },
#     "dt": 1611948182,
#     "id": 2629833,
#     "main": {
#         "feels_like": 5.67,
#         "humidity": 86,
#         "pressure": 1010,
#         "temp": 15.8,
#         "temp_max": 15.8,
#         "temp_min": 15.8
#     },
#     "name": "Husavik",
#     "sys": {
#         "country": "IS",
#         "id": 83,
#         "sunrise": 1611915374,
#         "sunset": 1611937716,
#         "type": 1
#     },
#     "timezone": 0,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "broken clouds",
#             "icon": "04n",
#             "id": 803,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 197,
#         "speed": 8.01
#     }
# }

# %%
#locating info in the open weather json

#latitude
response["coord"]["lat"]
# Out:
# 66.0449

# %%
#longitude
response["coord"]["lon"]
# Out:
# -17.3389

# %%
#temp
response["main"]["temp"]
# Out:
# 15.8

# %%
#humidity
response["main"]["humidity"]
# Out:
# 86

# %%
#cloudiness
response["clouds"]["all"]
# Out:
# 75

# %%
#wind
response["wind"]["speed"]
# Out:
# 8.01

# %%
#datetime
response["dt"]
# Out:
# 1611948182

# %%
#country, need it for the hotel map!
response["sys"]["country"]
# Out:
# 'IS'

# %%
for index, row in weather.iterrows():
    city = row["city"]
    
    not_json_yet = requests.get(f"http://api.openweathermap.org/data/2.5/weather?q={city}&appid={api_key}&units=imperial")
    
    if not_json_yet.status_code == 200:
        
        response = not_json_yet.json()
    
        weather.loc[index, "latitude"] = response["coord"]["lat"]
        weather.loc[index, "longitude"] = response["coord"]["lon"]
        weather.loc[index, "temperature"] = response["main"]["temp"]
        weather.loc[index, "humidity"] = response["main"]["humidity"]
        weather.loc[index, "cloudiness"] = response["clouds"]["all"]
        weather.loc[index, "wind"] = response["wind"]["speed"]
        weather.loc[index, "datetime"] = response["dt"]
        weather.loc[index, "country"] = response["sys"]["country"]
    
        print(f"Pulling weather for city #{index}, {city}")
    
        time.sleep(1)
        #to prevent maxing out the api call, thanks to Shaun in the class slack for the syntax
    
    else: 
        print(f"no data for city #{index}, {city}")
# Out:
# Pulling weather for city #0, punta arenas
# Pulling weather for city #1, kirovskiy
# Pulling weather for city #2, san cristobal
# Pulling weather for city #3, maningrida
# Pulling weather for city #4, necochea
# Pulling weather for city #5, kaitangata
# Pulling weather for city #6, ushuaia
# Pulling weather for city #7, cape town
# Pulling weather for city #8, cherskiy
# Pulling weather for city #9, jamestown
# Pulling weather for city #10, tasiilaq
# Pulling weather for city #11, rikitea
# Pulling weather for city #12, sao joao da barra
# Pulling weather for city #13, sinnamary
# Pulling weather for city #14, sept-iles
# Pulling weather for city #15, mataura
# Pulling weather for city #16, hilo
# Pulling weather for city #17, ust-nera
# Pulling weather for city #18, namibe
# Pulling weather for city #19, dalbandin
# Pulling weather for city #20, sistranda
# Pulling weather for city #21, meulaboh
# Pulling weather for city #22, tessalit
# Pulling weather for city #23, newtownards
# Pulling weather for city #24, pisco
# Pulling weather for city #25, hermanus
# Pulling weather for city #26, geraldton
# Pulling weather for city #27, chokurdakh
# Pulling weather for city #28, dolinsk
# Pulling weather for city #29, samarai
# Pulling weather for city #30, san juan
# Pulling weather for city #31, busselton
# Pulling weather for city #32, bluff
# Pulling weather for city #33, nanortalik
# Pulling weather for city #34, houston
# Pulling weather for city #35, acapulco
# Pulling weather for city #36, tocopilla
# Pulling weather for city #37, tuatapere
# Pulling weather for city #38, kodiak
# Pulling weather for city #39, hobart
# Pulling weather for city #40, akranes
# Pulling weather for city #41, salalah
# Pulling weather for city #42, longyearbyen
# Pulling weather for city #43, mykhaylivka
# Pulling weather for city #44, tiznit
# Pulling weather for city #45, fortuna
# Pulling weather for city #46, sao filipe
# Pulling weather for city #47, alta floresta
# Pulling weather for city #48, quimper
# Pulling weather for city #49, naples
# Pulling weather for city #50, kapaa
# Pulling weather for city #51, vaini
# Pulling weather for city #52, saint-philippe
# Pulling weather for city #53, quatre cocos
# Pulling weather for city #54, arlit
# Pulling weather for city #55, podgorica
# no data for city #56, cazaje
# no data for city #57, grand river south east
# Pulling weather for city #58, saskylakh
# Pulling weather for city #59, tuktoyaktuk
# Pulling weather for city #60, ostrovnoy
# Pulling weather for city #61, bochnia
# Pulling weather for city #62, yellowknife
# Pulling weather for city #63, port elizabeth
# Pulling weather for city #64, constitucion
# Pulling weather for city #65, beaverlodge
# Pulling weather for city #66, atuona
# Pulling weather for city #67, fort nelson
# Pulling weather for city #68, arraial do cabo
# Pulling weather for city #69, ahipara
# Pulling weather for city #70, ponta do sol
# Pulling weather for city #71, luderitz
# Pulling weather for city #72, verkhoyansk
# Pulling weather for city #73, kutum
# Pulling weather for city #74, ulundi
# Pulling weather for city #75, guiyang
# Pulling weather for city #76, uyuni
# Pulling weather for city #77, naryan-mar
# Pulling weather for city #78, inhambane
# Pulling weather for city #79, albany
# Pulling weather for city #80, butaritari
# Pulling weather for city #81, oksfjord
# no data for city #82, taolanaro
# Pulling weather for city #83, sabha
# Pulling weather for city #84, baykit
# Pulling weather for city #85, iisalmi
# Pulling weather for city #86, kavieng
# Pulling weather for city #87, salinopolis
# no data for city #88, santa eulalia del rio
# Pulling weather for city #89, assiniboia
# Pulling weather for city #90, joshimath
# no data for city #91, vaitupu
# Pulling weather for city #92, lethem
# Pulling weather for city #93, aklavik
# Pulling weather for city #94, urumqi
# Pulling weather for city #95, hithadhoo
# Pulling weather for city #96, nantucket
# Pulling weather for city #97, katsuura
# Pulling weather for city #98, safaga
# Pulling weather for city #99, ponnani
# Pulling weather for city #100, lukovetskiy
# Pulling weather for city #101, victoria
# Pulling weather for city #102, yar-sale
# Pulling weather for city #103, berlevag
# Pulling weather for city #104, nabire
# no data for city #105, zhetybay
# Pulling weather for city #106, seoul
# Pulling weather for city #107, mar del plata
# Pulling weather for city #108, aswan
# Pulling weather for city #109, marystown
# Pulling weather for city #110, bambous virieux
# Pulling weather for city #111, coahuayana
# Pulling weather for city #112, new norfolk
# Pulling weather for city #113, bredasdorp
# Pulling weather for city #114, hay river
# Pulling weather for city #115, nouadhibou
# Pulling weather for city #116, dikson
# Pulling weather for city #117, clyde river
# Pulling weather for city #118, general jose eduvigis diaz
# Pulling weather for city #119, armidale
# no data for city #120, barbar
# Pulling weather for city #121, alugan
# Pulling weather for city #122, marawi
# Pulling weather for city #123, evensk
# Pulling weather for city #124, torbay
# Pulling weather for city #125, san carlos de bariloche
# Pulling weather for city #126, chuy
# Pulling weather for city #127, waipawa
# Pulling weather for city #128, klaksvik
# Pulling weather for city #129, jibuti
# no data for city #130, illoqqortoormiut
# Pulling weather for city #131, saint-augustin
# Pulling weather for city #132, pacific grove
# Pulling weather for city #133, iqaluit
# Pulling weather for city #134, puerto ayora
# Pulling weather for city #135, hambantota
# Pulling weather for city #136, carnarvon
# Pulling weather for city #137, oudtshoorn
# Pulling weather for city #138, komsomolskiy
# Pulling weather for city #139, airai
# Pulling weather for city #140, sitka
# Pulling weather for city #141, muzhi
# Pulling weather for city #142, evanston
# Pulling weather for city #143, george town
# Pulling weather for city #144, cabo san lucas
# no data for city #145, barentsburg
# Pulling weather for city #146, bengkulu
# Pulling weather for city #147, vallenar
# Pulling weather for city #148, olafsvik
# Pulling weather for city #149, poum
# no data for city #150, mys shmidta
# Pulling weather for city #151, broken hill
# Pulling weather for city #152, beloha
# Pulling weather for city #153, novo aripuana
# Pulling weather for city #154, rincon
# Pulling weather for city #155, lagoa
# Pulling weather for city #156, dhidhdhoo
# Pulling weather for city #157, karatsu
# Pulling weather for city #158, saint george
# Pulling weather for city #159, kysyl-syr
# no data for city #160, samusu
# Pulling weather for city #161, pitkyaranta
# Pulling weather for city #162, la ronge
# Pulling weather for city #163, port alfred
# Pulling weather for city #164, tiksi
# Pulling weather for city #165, qaanaaq
# Pulling weather for city #166, chapais
# Pulling weather for city #167, ati
# Pulling weather for city #168, pangnirtung
# Pulling weather for city #169, guangyuan
# Pulling weather for city #170, tabuk
# Pulling weather for city #171, leningradskiy
# Pulling weather for city #172, half moon bay
# Pulling weather for city #173, yerofey pavlovich
# Pulling weather for city #174, georgetown
# Pulling weather for city #175, nome
# Pulling weather for city #176, te anau
# Pulling weather for city #177, thompson
# Pulling weather for city #178, broome
# Pulling weather for city #179, muros
# Pulling weather for city #180, norman wells
# Pulling weather for city #181, venado tuerto
# no data for city #182, galgani
# Pulling weather for city #183, kruisfontein
# Pulling weather for city #184, honiara
# Pulling weather for city #185, qujing
# Pulling weather for city #186, vestmannaeyjar
# Pulling weather for city #187, aasiaat
# Pulling weather for city #188, kedougou
# Pulling weather for city #189, el tigre
# Pulling weather for city #190, brooks
# no data for city #191, belushya guba
# Pulling weather for city #192, bogande
# Pulling weather for city #193, omboue
# Pulling weather for city #194, xam nua
# Pulling weather for city #195, dunedin
# Pulling weather for city #196, talnakh
# Pulling weather for city #197, khatanga
# Pulling weather for city #198, bathsheba
# Pulling weather for city #199, castro
# Pulling weather for city #200, along
# Pulling weather for city #201, mahebourg
# Pulling weather for city #202, maniitsoq
# Pulling weather for city #203, vanimo
# Pulling weather for city #204, codrington
# Pulling weather for city #205, banjarmasin
# Pulling weather for city #206, kodinsk
# Pulling weather for city #207, nhulunbuy
# Pulling weather for city #208, grajau
# Pulling weather for city #209, milkovo
# Pulling weather for city #210, omsukchan
# Pulling weather for city #211, mandasa
# Pulling weather for city #212, xinzhou
# Pulling weather for city #213, carupano
# Pulling weather for city #214, tazovskiy
# Pulling weather for city #215, alofi
# Pulling weather for city #216, guerrero negro
# Pulling weather for city #217, sao jose da coroa grande
# Pulling weather for city #218, anloga
# Pulling weather for city #219, rogatica
# Pulling weather for city #220, port lincoln
# Pulling weather for city #221, tarko-sale
# Pulling weather for city #222, the valley
# no data for city #223, mendahara
# Pulling weather for city #224, ust-omchug
# Pulling weather for city #225, lompoc
# Pulling weather for city #226, barrow
# Pulling weather for city #227, ucluelet
# Pulling weather for city #228, port hedland
# Pulling weather for city #229, touros
# Pulling weather for city #230, calarasi
# Pulling weather for city #231, morros
# Pulling weather for city #232, fukuma
# Pulling weather for city #233, troitskoye
# Pulling weather for city #234, pontes e lacerda
# no data for city #235, saleaula
# Pulling weather for city #236, twentynine palms
# Pulling weather for city #237, brae
# Pulling weather for city #238, vilhena
# Pulling weather for city #239, cayenne
# Pulling weather for city #240, upernavik
# Pulling weather for city #241, aksarka
# Pulling weather for city #242, vila franca do campo
# Pulling weather for city #243, traverse city
# Pulling weather for city #244, xiongzhou
# Pulling weather for city #245, oriximina
# Pulling weather for city #246, nishihara
# Pulling weather for city #247, nemuro
# Pulling weather for city #248, dhuwaran
# Pulling weather for city #249, boyolangu
# Pulling weather for city #250, narsaq
# Pulling weather for city #251, coihaique
# Pulling weather for city #252, mujiayingzi
# Pulling weather for city #253, krasnoselkup
# Pulling weather for city #254, jalu
# Pulling weather for city #255, goderich
# Pulling weather for city #256, sakakah
# no data for city #257, ferai
# Pulling weather for city #258, sisimiut
# Pulling weather for city #259, bethel
# Pulling weather for city #260, faanui
# Pulling weather for city #261, ribeira grande
# Pulling weather for city #262, hornepayne
# Pulling weather for city #263, amberley
# Pulling weather for city #264, comodoro rivadavia
# no data for city #265, yuzhno-yeniseyskiy
# Pulling weather for city #266, teya
# Pulling weather for city #267, nampula
# Pulling weather for city #268, yulara
# Pulling weather for city #269, beyneu
# Pulling weather for city #270, mangaratiba
# Pulling weather for city #271, kenai
# Pulling weather for city #272, kobelyaky
# Pulling weather for city #273, lacey
# Pulling weather for city #274, provideniya
# Pulling weather for city #275, valparaiso
# Pulling weather for city #276, grants pass
# Pulling weather for city #277, launceston
# Pulling weather for city #278, buta
# Pulling weather for city #279, hasaki
# Pulling weather for city #280, hamilton
# Pulling weather for city #281, calabozo
# Pulling weather for city #282, makinsk
# Pulling weather for city #283, pansoy
# Pulling weather for city #284, talmenka
# Pulling weather for city #285, palmer
# no data for city #286, sidi bu zayd
# Pulling weather for city #287, cedar city
# Pulling weather for city #288, palasbari
# Pulling weather for city #289, freetown
# Pulling weather for city #290, diamantino
# Pulling weather for city #291, lincoln
# Pulling weather for city #292, katherine
# Pulling weather for city #293, sande
# Pulling weather for city #294, rodgau
# Pulling weather for city #295, naze
# Pulling weather for city #296, itarema
# Pulling weather for city #297, keti bandar
# Pulling weather for city #298, rongcheng
# Pulling weather for city #299, buraydah
# Pulling weather for city #300, shingu
# Pulling weather for city #301, hyderabad
# Pulling weather for city #302, nioaque
# Pulling weather for city #303, dossor
# Pulling weather for city #304, batticaloa
# Pulling weather for city #305, flagstaff
# Pulling weather for city #306, tiarei
# no data for city #307, karaul
# Pulling weather for city #308, etchoropo
# Pulling weather for city #309, awbari
# Pulling weather for city #310, eureka
# no data for city #311, taburi
# Pulling weather for city #312, tezu
# Pulling weather for city #313, carauari
# Pulling weather for city #314, lorengau
# Pulling weather for city #315, khash
# Pulling weather for city #316, bonga
# Pulling weather for city #317, seydisehir
# no data for city #318, sentyabrskiy
# Pulling weather for city #319, haines junction
# Pulling weather for city #320, saldanha
# Pulling weather for city #321, ossora
# Pulling weather for city #322, avarua
# Pulling weather for city #323, allapalli
# Pulling weather for city #324, saint-pierre
# Pulling weather for city #325, kavaratti
# Pulling weather for city #326, izvestkovyy
# Pulling weather for city #327, goya
# Pulling weather for city #328, nisia floresta
# Pulling weather for city #329, acopiara
# no data for city #330, tsihombe
# Pulling weather for city #331, khao wong
# no data for city #332, attawapiskat
# Pulling weather for city #333, oranjestad
# no data for city #334, skalistyy
# Pulling weather for city #335, corinth
# Pulling weather for city #336, sobolevo
# Pulling weather for city #337, paamiut
# Pulling weather for city #338, fort-shevchenko
# Pulling weather for city #339, aneho
# Pulling weather for city #340, basco
# Pulling weather for city #341, severo-kurilsk
# Pulling weather for city #342, kiama
# Pulling weather for city #343, aden
# Pulling weather for city #344, candido mendes
# Pulling weather for city #345, juneau
# Pulling weather for city #346, ingham
# Pulling weather for city #347, northam
# Pulling weather for city #348, biak
# Pulling weather for city #349, anadyr
# Pulling weather for city #350, yokadouma
# Pulling weather for city #351, svetlogorsk
# Pulling weather for city #352, letterkenny
# Pulling weather for city #353, loreto
# Pulling weather for city #354, puerto narino
# Pulling weather for city #355, pangai
# Pulling weather for city #356, alice springs
# no data for city #357, maloshuyka
# Pulling weather for city #358, kitimat
# Pulling weather for city #359, tel aviv-yafo
# Pulling weather for city #360, shimoda
# Pulling weather for city #361, kununurra
# Pulling weather for city #362, pevek
# Pulling weather for city #363, victor harbor
# Pulling weather for city #364, olden
# Pulling weather for city #365, ranong
# no data for city #366, sorvag
# Pulling weather for city #367, samarina
# Pulling weather for city #368, hirara
# Pulling weather for city #369, lebu
# Pulling weather for city #370, vuktyl
# no data for city #371, temaraia
# Pulling weather for city #372, aplahoue
# Pulling weather for city #373, moron
# Pulling weather for city #374, toktogul
# Pulling weather for city #375, port augusta
# Pulling weather for city #376, cao bang
# no data for city #377, brahmapuri
# no data for city #378, barawe
# Pulling weather for city #379, damghan
# Pulling weather for city #380, sangar
# Pulling weather for city #381, walvis bay
# Pulling weather for city #382, turukhansk
# Pulling weather for city #383, sechelt
# no data for city #384, tubruq
# Pulling weather for city #385, elat
# no data for city #386, rungata
# Pulling weather for city #387, ulladulla
# Pulling weather for city #388, faya
# Pulling weather for city #389, hoquiam
# Pulling weather for city #390, yerbogachen
# Pulling weather for city #391, chernyshevskiy
# Pulling weather for city #392, mahibadhoo
# Pulling weather for city #393, jinan
# Pulling weather for city #394, altus
# Pulling weather for city #395, svobodnyy
# Pulling weather for city #396, charleston
# Pulling weather for city #397, ascope
# Pulling weather for city #398, kot diji
# Pulling weather for city #399, bacalan
# no data for city #400, eskasem
# Pulling weather for city #401, souillac
# Pulling weather for city #402, orda
# no data for city #403, marcona
# Pulling weather for city #404, sonoita
# Pulling weather for city #405, ahuimanu
# Pulling weather for city #406, madera
# Pulling weather for city #407, awjilah
# Pulling weather for city #408, kochubey
# Pulling weather for city #409, petropavlovsk-kamchatskiy
# Pulling weather for city #410, sungaipenuh
# Pulling weather for city #411, wawa
# Pulling weather for city #412, mansa
# Pulling weather for city #413, kataysk
# Pulling weather for city #414, sault sainte marie
# Pulling weather for city #415, dingle
# no data for city #416, grand centre
# Pulling weather for city #417, ancud
# Pulling weather for city #418, skibbereen
# Pulling weather for city #419, gravdal
# Pulling weather for city #420, mocuba
# Pulling weather for city #421, beringovskiy
# Pulling weather for city #422, bubaque
# Pulling weather for city #423, ilulissat
# Pulling weather for city #424, hofn
# Pulling weather for city #425, fairbanks
# Pulling weather for city #426, bougouni
# Pulling weather for city #427, rehoboth
# Pulling weather for city #428, berdigestyakh
# Pulling weather for city #429, green river
# Pulling weather for city #430, cidreira
# Pulling weather for city #431, kezmarok
# Pulling weather for city #432, college
# Pulling weather for city #433, turkmenabat
# Pulling weather for city #434, porto seguro
# Pulling weather for city #435, tarauaca
# Pulling weather for city #436, mpongwe
# Pulling weather for city #437, east london
# Pulling weather for city #438, dengzhou
# Pulling weather for city #439, bowen
# Pulling weather for city #440, tucuman
# Pulling weather for city #441, tangi
# no data for city #442, tasbuget
# Pulling weather for city #443, nayagarh
# Pulling weather for city #444, raga
# Pulling weather for city #445, port hardy
# Pulling weather for city #446, jha jha
# Pulling weather for city #447, santiago del estero
# Pulling weather for city #448, yatou
# Pulling weather for city #449, namatanai
# Pulling weather for city #450, mino
# Pulling weather for city #451, manokwari
# Pulling weather for city #452, harper
# Pulling weather for city #453, madang
# Pulling weather for city #454, portland
# Pulling weather for city #455, wattegama
# Pulling weather for city #456, caravelas
# Pulling weather for city #457, bairnsdale
# Pulling weather for city #458, seminole
# Pulling weather for city #459, bilibino
# no data for city #460, amderma
# Pulling weather for city #461, labuan
# Pulling weather for city #462, srednekolymsk
# Pulling weather for city #463, port said
# Pulling weather for city #464, qasigiannguit
# Pulling weather for city #465, sandpoint
# Pulling weather for city #466, buchanan
# Pulling weather for city #467, kijang
# Pulling weather for city #468, sonqor
# Pulling weather for city #469, aksu
# Pulling weather for city #470, bandung
# Pulling weather for city #471, pochinki
# Pulling weather for city #472, polis
# Pulling weather for city #473, shakawe
# Pulling weather for city #474, roald
# Pulling weather for city #475, magdalena
# Pulling weather for city #476, chatham
# Pulling weather for city #477, kushima
# no data for city #478, po
# Pulling weather for city #479, hami
# Pulling weather for city #480, ust-uda
# Pulling weather for city #481, bulawayo
# Pulling weather for city #482, colesberg
# Pulling weather for city #483, pyu
# Pulling weather for city #484, aripuana
# Pulling weather for city #485, russell
# no data for city #486, baboua
# no data for city #487, dianopolis
# Pulling weather for city #488, dunmore town
# Pulling weather for city #489, cockburn town
# Pulling weather for city #490, westport
# Pulling weather for city #491, cabra
# Pulling weather for city #492, campoverde
# Pulling weather for city #493, bindura
# Pulling weather for city #494, lazarev
# Pulling weather for city #495, volkhov
# Pulling weather for city #496, nikolskoye
# no data for city #497, karamay
# Pulling weather for city #498, aban
# Pulling weather for city #499, bethanien
# Pulling weather for city #500, polovinnoye
# Pulling weather for city #501, umm kaddadah
# Pulling weather for city #502, san quintin
# Pulling weather for city #503, caronport
# Pulling weather for city #504, honningsvag
# Pulling weather for city #505, esperance
# Pulling weather for city #506, karratha
# Pulling weather for city #507, laguna
# Pulling weather for city #508, mugur-aksy
# Pulling weather for city #509, mareeba
# Pulling weather for city #510, bani walid
# Pulling weather for city #511, guanica
# Pulling weather for city #512, atar
# Pulling weather for city #513, ballina
# Pulling weather for city #514, sandeid
# Pulling weather for city #515, olinda
# Pulling weather for city #516, port-cartier
# Pulling weather for city #517, port macquarie
# Pulling weather for city #518, kananga
# Pulling weather for city #519, zhigansk
# Pulling weather for city #520, banjar
# Pulling weather for city #521, noumea
# no data for city #522, nizhneyansk
# Pulling weather for city #523, det udom
# Pulling weather for city #524, mexico
# Pulling weather for city #525, altay
# Pulling weather for city #526, pagudpud
# Pulling weather for city #527, kostomuksha
# Pulling weather for city #528, san buenaventura
# Pulling weather for city #529, nizhnevartovsk
# Pulling weather for city #530, ocampo
# no data for city #531, khonuu
# no data for city #532, jomalig
# Pulling weather for city #533, vila velha
# Pulling weather for city #534, hualmay
# Pulling weather for city #535, zdvinsk
# Pulling weather for city #536, banamba
# Pulling weather for city #537, avdon
# Pulling weather for city #538, balkanabat
# Pulling weather for city #539, lansing
# Pulling weather for city #540, winnemucca
# Pulling weather for city #541, belmonte
# Pulling weather for city #542, praia
# no data for city #543, mutsamudu
# no data for city #544, ondorhaan
# Pulling weather for city #545, glyadyanskoye
# Pulling weather for city #546, wufeng
# Pulling weather for city #547, elko
# no data for city #548, meerzorg
# Pulling weather for city #549, huangchuan
# Pulling weather for city #550, peace river
# Pulling weather for city #551, daru
# Pulling weather for city #552, itoman
# Pulling weather for city #553, okha
# Pulling weather for city #554, jeremie
# Pulling weather for city #555, kirakira
# Pulling weather for city #556, bilma
# Pulling weather for city #557, kaoma
# Pulling weather for city #558, cochabamba
# Pulling weather for city #559, lloydminster
# Pulling weather for city #560, virginia beach
# Pulling weather for city #561, knysna
# no data for city #562, cheuskiny
# Pulling weather for city #563, luau
# Pulling weather for city #564, hobyo
# Pulling weather for city #565, canguaretama
# Pulling weather for city #566, fernan-nunez
# Pulling weather for city #567, la union
# Pulling weather for city #568, cabinda
# no data for city #569, tumannyy
# Pulling weather for city #570, nam som
# Pulling weather for city #571, marsa matruh
# Pulling weather for city #572, krasnokamensk
# Pulling weather for city #573, izyaslav
# Pulling weather for city #574, dalby
# Pulling weather for city #575, youghal
# Pulling weather for city #576, belaya gora
# Pulling weather for city #577, port-gentil
# Pulling weather for city #578, buala
# Pulling weather for city #579, bereda
# Pulling weather for city #580, kommunar
# Pulling weather for city #581, xining
# Pulling weather for city #582, tabas
# Pulling weather for city #583, tigil
# Pulling weather for city #584, duluth
# Pulling weather for city #585, loandjili
# Pulling weather for city #586, cascais
# Pulling weather for city #587, khandyga
# Pulling weather for city #588, istok
# Pulling weather for city #589, hvide sande
# Pulling weather for city #590, san patricio
# Pulling weather for city #591, pozo colorado
# Pulling weather for city #592, mungwi
# no data for city #593, palabuhanratu
# Pulling weather for city #594, iberia
# Pulling weather for city #595, vysokogornyy
# Pulling weather for city #596, vetapalem
# Pulling weather for city #597, moerai
# Pulling weather for city #598, svetlaya
# Pulling weather for city #599, port arthur
# Pulling weather for city #600, effium
# Pulling weather for city #601, sipe sipe
# Pulling weather for city #602, kokstad
# Pulling weather for city #603, grand gaube
# Pulling weather for city #604, mana
# Pulling weather for city #605, henties bay
# Pulling weather for city #606, jieshi
# Pulling weather for city #607, sibolga
# no data for city #608, guelengdeng
# Pulling weather for city #609, banda aceh
# no data for city #610, utiroa
# no data for city #611, sataua
# Pulling weather for city #612, san fernando
# Pulling weather for city #613, havelock
# Pulling weather for city #614, santa cruz
# Pulling weather for city #615, sehithwa
# Pulling weather for city #616, las vegas
# Pulling weather for city #617, saint-joseph
# Pulling weather for city #618, suvorov
# Pulling weather for city #619, mayo
# Pulling weather for city #620, batagay-alyta
# Pulling weather for city #621, tungor
# Pulling weather for city #622, santa marta
# Pulling weather for city #623, baghdad
# Pulling weather for city #624, mirnyy
# Pulling weather for city #625, kudymkar
# Pulling weather for city #626, haimen
# Pulling weather for city #627, kargil
# Pulling weather for city #628, howard springs
# Pulling weather for city #629, brokopondo
# Pulling weather for city #630, constantine

# %%
weather
# Out:
#                city latitude longitude temperature humidity cloudiness   wind  \
# 0      punta arenas   -53.15  -70.9167       48.09       66         75  25.32
# 1         kirovskiy  45.0917   133.514      -23.69       86          4   2.57
# 2     san cristobal   7.7669   -72.225        84.2       58         40   13.8
# 3        maningrida -12.0667   134.267        76.3       91         81   6.11
# 4          necochea -38.5473  -58.7368       78.01       42         35    6.8
# ..              ...      ...       ...         ...      ...        ...    ...
# 626          haimen  23.1935   116.614        51.8       66          0   4.47
# 627          kargil  34.5667      76.1      -10.07       78          6   1.74
# 628  howard springs  -12.497   131.047       74.71      100         90  21.85
# 629      brokopondo     4.75  -55.1667       79.81       85        100   7.58
# 630     constantine   36.365    6.6147        57.2       62          0  10.36
#
#        datetime country
# 0    1611948215      CL
# 1    1611948216      RU
# 2    1611947928      VE
# 3    1611948218      AU
# 4    1611948219      AR
# ..          ...     ...
# 626  1611948902      CN
# 627  1611948904      IN
# 628  1611948905      AU
# 629  1611948906      SR
# 630  1611948907      DZ
#
# [631 rows x 9 columns]

# %%
# dropping the rows that didn't get any info returned in the api call
weather.drop(weather.loc[weather["latitude"] == "",:].index, inplace=True)
# borrowed from https://stackoverflow.com/questions/13851535/how-to-delete-rows-from-a-pandas-dataframe-based-on-a-conditional-expression

# %%
weather
# Out:
#                city latitude longitude temperature humidity cloudiness   wind  \
# 0      punta arenas   -53.15  -70.9167       48.09       66         75  25.32
# 1         kirovskiy  45.0917   133.514      -23.69       86          4   2.57
# 2     san cristobal   7.7669   -72.225        84.2       58         40   13.8
# 3        maningrida -12.0667   134.267        76.3       91         81   6.11
# 4          necochea -38.5473  -58.7368       78.01       42         35    6.8
# ..              ...      ...       ...         ...      ...        ...    ...
# 626          haimen  23.1935   116.614        51.8       66          0   4.47
# 627          kargil  34.5667      76.1      -10.07       78          6   1.74
# 628  howard springs  -12.497   131.047       74.71      100         90  21.85
# 629      brokopondo     4.75  -55.1667       79.81       85        100   7.58
# 630     constantine   36.365    6.6147        57.2       62          0  10.36
#
#        datetime country
# 0    1611948215      CL
# 1    1611948216      RU
# 2    1611947928      VE
# 3    1611948218      AU
# 4    1611948219      AR
# ..          ...     ...
# 626  1611948902      CN
# 627  1611948904      IN
# 628  1611948905      AU
# 629  1611948906      SR
# 630  1611948907      DZ
#
# [579 rows x 9 columns]

# %%
#printing to csv
weather.to_csv("results/weather_data.csv", index=False)

# %%
# scatter plots

# data note: my cities list doesn't have any latitudes below -60, but it's not a sampling
# problem. There just aren't any cities below that latitude!

# %%
plt.scatter(weather["latitude"], weather["temperature"])
plt.title("Latitude vs. Temperature")
plt.ylabel("Temperature")
plt.xlabel("Latitude")
plt.savefig("results/temperature.png")

# %%
# Each dot in this scatterplot represents one city. Its position on the x axis shows 
# how farth north or south it is on earth, with 0 as the equator. Its position on the 
# y axis shows how hot it was there at the time the data was pulled.

# %%
plt.scatter(weather["latitude"], weather["humidity"])
plt.title("Latitude vs. Humidity")
plt.ylabel("Humidity")
plt.xlabel("Latitude")
plt.savefig("results/humidity.png")

# %%
# Each dot in this scatterplot represents one city. Its position on the x axis shows 
# how farth north or south it is on earth, with 0 as the equator. Its position on the 
# y axis shows how humid it was there at the time the data was pulled.

# %%
plt.scatter(weather["latitude"], weather["cloudiness"])
plt.title("Latitude vs. Cloudiness")
plt.ylabel("Cloudiness")
plt.xlabel("Latitude")
plt.savefig("results/clouds.png")

# %%
# Each dot in this scatterplot represents one city. Its position on the x axis shows how 
# farth north or south it is on earth, with 0 as the equator. Its position on the y axis 
# shows how cloudy it was there at the time the data was pulled. The horizontal bands 
# probably mean that the data isn't precise down to 1% - many data points are 
# probably estimates of 0%, 20%, 40% etc. cloud cover.

# %%
plt.scatter(weather["latitude"], weather["wind"])
plt.title("Latitude vs. Wind Speed")
plt.ylabel("Wind Speed")
plt.xlabel("Latitude")
plt.savefig("results/wind.png")

# %%
# Each dot in this scatterplot represents one city. Its position on the x axis shows how 
# farth north or south it is on earth, with 0 as the equator. Its position on the y axis 
# shows the wind speed at the time the data was pulled.

# %%
#regressions! splitting the data into northern vs southern hemisphere and plotting from each one.

# %%
north = weather.loc[weather["latitude"]>0,:]
south = weather.loc[weather["latitude"]<=0,:]

# %%
fig, (south_sub, north_sub) = plt.subplots(nrows=1, ncols=2, sharey=True, figsize=(12, 6))
fig.suptitle("Latitude vs. Temperature")
south_sub.set_ylabel("Temperature")

south_sub.scatter(south["latitude"],south["temperature"])
south_sub.set_title("Southern Hemisphere")

(south_slope, south_intercept, south_rvalue, south_pvalue, south_stderr) = linregress(south["latitude"].astype(float),south["temperature"].astype(float))
south_regress = south["latitude"] * south_slope + south_intercept
south_line = "y = " + str(round(south_slope,2)) + "x + " + str(round(south_intercept,2))

south_sub.plot(south["latitude"],south_regress,"r-")
south_sub.annotate(south_line,(-40,0),fontsize=15,color="red")


north_sub.scatter(north["latitude"],north["temperature"])
north_sub.set_title("Northern Hemisphere")

(north_slope, north_intercept, north_rvalue, north_pvalue, north_stderr) = linregress(north["latitude"].astype(float),north["temperature"].astype(float))
north_regress = north["latitude"] * north_slope + north_intercept
north_line = "y = " + str(round(north_slope,2)) + "x + " + str(round(north_intercept,2))

north_sub.plot(north["latitude"],north_regress,"r-")
north_sub.annotate(north_line,(5,-30),fontsize=15,color="red")

plt.savefig("results/N&S temperature with regressions.png")

# cast df columns as floats based on this thread: https://stackoverflow.com/questions/53200129/attributeerror-float-object-has-no-attribute-shape-when-using-linregress
# after getting an error in the linear regression

# %%
# The linear regression shows how much temperature varies with latitude in each hemisphere 
# at the time the data was pulled. In each case, temperature decreases with latitudes farther 
# away from the equator. At the moment it varies much more with latitude in the northern 
# hemisphere, most likely because it is winter here, so temperatures are able to get lower.
# But, I expect that if we re ran this in July, we would still not see as strong a correlation 
# in southern hemisphere as we do now for the northern hemisphere, because the cities in 
# the southern hemisphere are much more clustered in the tropical & subtropical regions (about
# <35 degrees latitude) where temperatures vary less with the seasons.

# %%
fig, (south_sub, north_sub) = plt.subplots(nrows=1, ncols=2, sharey=True, figsize=(12, 6))
fig.suptitle("Latitude vs. Humidity")
south_sub.set_ylabel("Humidity")

south_sub.scatter(south["latitude"],south["humidity"])
south_sub.set_title("Southern Hemisphere")

(south_slope, south_intercept, south_rvalue, south_pvalue, south_stderr) = linregress(south["latitude"].astype(float),south["humidity"].astype(float))
south_regress = south["latitude"] * south_slope + south_intercept
south_line = "y = " + str(round(south_slope,2)) + "x + " + str(round(south_intercept,2))

south_sub.plot(south["latitude"],south_regress,"r-")
south_sub.annotate(south_line,(-40,10),fontsize=15,color="red")


north_sub.scatter(north["latitude"],north["humidity"])
north_sub.set_title("Northern Hemisphere")

(north_slope, north_intercept, north_rvalue, north_pvalue, north_stderr) = linregress(north["latitude"].astype(float),north["humidity"].astype(float))
north_regress = north["latitude"] * north_slope + north_intercept
north_line = "y = " + str(round(north_slope,2)) + "x + " + str(round(north_intercept,2))

north_sub.plot(north["latitude"],north_regress,"r-")
north_sub.annotate(north_line,(40,20),fontsize=15,color="red")

plt.savefig("results/N&S humidity with regressions.png")

# %%
# The linear regression shows how much humidity varies with latitude in each hemisphere at 
# the time the data was pulled. In the southern hemisphere, humidity increases as latitudes 
# approach the equator, but in the northern hemisphere, they decrease. The Northern
# hemisphere's results are strongly affected by the sahara desert (lat 0-30 and of course, 
# very dry). We can see that that is where almost all of the driest cities in the northern 
# hemisphere are:

north.loc[north["humidity"]<30,:]
# Out:
#              city latitude longitude temperature humidity cloudiness   wind  \
# 19      dalbandin  28.8947   64.4101       52.81       29        100   5.32
# 22       tessalit  20.1986    1.0114       69.19       19          0  10.02
# 54          arlit  18.7369    7.3853       69.42       20          3   11.5
# 73          kutum     14.2   24.6667       60.87       29         18  13.49
# 167           ati  13.2154   18.3353       78.12       16          0  14.41
# 188      kedougou  12.5579  -12.1743        96.8       13          0   6.91
# 192       bogande  12.9714   -0.1436       79.97       16          0    9.6
# 248      dhuwaran  22.2333      72.8       62.91       27         73   8.88
# 250        narsaq  60.9167    -46.05        44.6       29         75  24.16
# 281      calabozo   8.9242  -67.4293       95.58       28         39   7.92
# 411          wawa   9.9022    4.4192       83.52       15         15   3.49
# 426      bougouni   11.417    -7.479       80.76       14         89   3.27
# 433   turkmenabat  39.0733   63.5786        51.8       24         48   11.5
# 444          raga   8.4596    25.678        75.4       18         18   6.58
# 485       russell  32.3502  -85.1999       55.29       28          1   2.26
# 501  umm kaddadah  13.6017   26.6876       67.82       24          0  18.39
# 512          atar  20.5169  -13.0499       73.51       19          0   8.66
# 536       banamba    13.55     -7.45       76.86       16          0   7.54
# 556         bilma  18.6853   12.9164       63.93       26         23   5.68
# 582         tabas  33.5959   56.9244          50       17         68   4.61
# 600        effium   6.6292    8.0593        82.4       14          0   3.94
#
#        datetime country
# 19   1611948236      PK
# 22   1611948240      ML
# 54   1611948277      NE
# 73   1611948296      SD
# 167  1611948395      TD
# 188  1611948418      SN
# 192  1611948421      BF
# 248  1611948484      IN
# 250  1611948487      GL
# 281  1611948521      VE
# 411  1611948656      NG
# 426  1611948672      ML
# 433  1611948681      TM
# 444  1611948692      SS
# 485  1611948741      US
# 501  1611948757      SD
# 512  1611948769      MR
# 536  1611948796      ML
# 556  1611948817      NE
# 582  1611948849      IR
# 600  1611948872      NG

# %%
fig, (south_sub, north_sub) = plt.subplots(nrows=1, ncols=2, sharey=True, figsize=(12, 6))
fig.suptitle("Latitude vs. Cloudiness")
south_sub.set_ylabel("% Cloud Cover")

south_sub.scatter(south["latitude"],south["cloudiness"])
south_sub.set_title("Southern Hemisphere")

(south_slope, south_intercept, south_rvalue, south_pvalue, south_stderr) = linregress(south["latitude"].astype(float),south["cloudiness"].astype(float))
south_regress = south["latitude"] * south_slope + south_intercept
south_line = "y = " + str(round(south_slope,2)) + "x + " + str(round(south_intercept,2))

south_sub.plot(south["latitude"],south_regress,"r-")
south_sub.annotate(south_line,(-50,60),fontsize=15,color="red")

north_sub.scatter(north["latitude"],north["cloudiness"])
north_sub.set_title("Northern Hemisphere")

(north_slope, north_intercept, north_rvalue, north_pvalue, north_stderr) = linregress(north["latitude"].astype(float),north["cloudiness"].astype(float))
north_regress = north["latitude"] * north_slope + north_intercept
north_line = "y = " + str(round(north_slope,2)) + "x + " + str(round(north_intercept,2))

north_sub.plot(north["latitude"],north_regress,"r-")
north_sub.annotate(north_line,(40,45),fontsize=15,color="red")

plt.savefig("results/N&S cloud cover with regressions.png")

# %%
# The linear regression shows how much humidity varies with latitude in each hemisphere 
# at the time the data was pulled. In the southern hemisphere, cloud cover increases as 
# latitudes approach the equator, but in the northern hemisphere, it decreases. This is 
# most likely an effect of humidity.

# %%
fig, (south_sub, north_sub) = plt.subplots(nrows=1, ncols=2, sharey=True, figsize=(12, 6))
fig.suptitle("Latitude vs. Wind Speed")
south_sub.set_ylabel("Wind Speed")

south_sub.scatter(south["latitude"],south["wind"])
south_sub.set_title("Southern Hemisphere")

(south_slope, south_intercept, south_rvalue, south_pvalue, south_stderr) = linregress(south["latitude"].astype(float),south["wind"].astype(float))
south_regress = south["latitude"] * south_slope + south_intercept
south_line = "y = " + str(round(south_slope,2)) + "x + " + str(round(south_intercept,2))

south_sub.plot(south["latitude"],south_regress,"r-")
south_sub.annotate(south_line,(-40,30),fontsize=15,color="red")

north_sub.scatter(north["latitude"],north["wind"])
north_sub.set_title("Northern Hemisphere")

(north_slope, north_intercept, north_rvalue, north_pvalue, north_stderr) = linregress(north["latitude"].astype(float),north["wind"].astype(float))
north_regress = north["latitude"] * north_slope + north_intercept
north_line = "y = " + str(round(north_slope,2)) + "x + " + str(round(north_intercept,2))

north_sub.plot(north["latitude"],north_regress,"r-")
north_sub.annotate(north_line,(0,30),fontsize=15,color="red")

plt.savefig("results/N&S wind speed with regressions.png")

# %%
# The linear regression shows how much wind speed varies with latitude in each hemisphere 
# at the time the data was pulled. In both hemispheres there is no strong correlation,
# but every time I've run it you can spot Tierra Del Fuego (latitude <-50 and always really 
# stormy), and usually a great cluster of windy cities around 40 degrees north, in the 
# path of the trade winds

# %%
#Tierra Del Fuego!

weather.loc[weather["latitude"]<-50,:]
# Out:
#            city latitude longitude temperature humidity cloudiness   wind  \
# 0  punta arenas   -53.15  -70.9167       48.09       66         75  25.32
# 6       ushuaia    -54.8     -68.3        42.8       70         75  23.02
#
#      datetime country
# 0  1611948215      CL
# 6  1611947996      AR
